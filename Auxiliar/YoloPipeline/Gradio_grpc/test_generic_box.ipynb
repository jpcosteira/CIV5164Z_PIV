# %%
# Test for the estimation of a single image key-points

import argparse
import grpc
import io
import matplotlib.pyplot as plt
import generic_box_pb2
import generic_box_pb2_grpc
from scipy.io import savemat, loadmat
import PIL.Image as PIL_image
import cv2 as cv

# %% [markdown]
# ## These functions assume the matlab file has one image in variable "image"

# %%
def process_image(stub, image_path):
    print(f'Processing image: \'{image_path}\'')

    img = PIL_image.open("img.png")
    dic = {'im0':img}
    print(type(dic))

    savemat("temp2.mat",dic)
    with open("temp2.mat", 'rb') as fp:
        image_bytes = fp.read()

    savemat("temp1.mat",{})
    with open("temp1.mat", 'rb') as fp:
        matfile = fp.read()
    request = generic_box_pb2.YoloData(data2=image_bytes,data1=matfile)
    stub.display(request)


def display_image(stub):
    Data = stub.submit(generic_box_pb2.Empty())
    dados=loadmat(io.BytesIO(Data.file))
    #img = PIL_image.open(io.BytesIO(image.data))
    img=dados['im']
    ax = plt.gca()
    ax.imshow(img)
    plt.show()

# %% [markdown]
# ### Rotina de teste: cria stub para o serviço,chama função que envia mensagem
# Target - Nó onde está a correr o serviço

# %%
    target = 'localhost:8061'
    image_path = "img.mat"
    with grpc.insecure_channel(target) as channel:
        estimator_stub = generic_box_pb2_grpc.GenericBoxServiceStub(channel)
        try:
            display_image(estimator_stub)
            process_image(estimator_stub, image_path)
        except grpc.RpcError as rpc_error:
            print('An error has occurred:')
            print(f'  Error Code: {rpc_error.code()}')
            print(f'  Details: {rpc_error.details()}')
# Out:
# Processing image: 'img.mat'
# <class 'dict'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 7
#       5 try:
#       6     display_image(estimator_stub)
# ----> 7     process_image(estimator_stub, image_path)
#       8 except grpc.RpcError as rpc_error:
#       9     print('An error has occurred:')
#
# Cell In[32], line 8, in process_image(stub, image_path)
#       5 dic = {'im0':img}
#       6 print(type(dic))
# ----> 8 savemat("temp2.mat",dic)
#       9 with open("temp2.mat", 'rb') as fp:
#      10     image_bytes = fp.read()
#
# File c:\Users\Gil Beirao\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\io\matlab\_mio.py:300, in savemat(file_name, mdict, appendmat, format, long_field_names, do_compression, oned_as)
#     298 else:
#     299     raise ValueError("Format should be '4' or '5'")
# --> 300 MW.put_variables(mdict)
#
# File c:\Users\Gil Beirao\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\io\matlab\_mio5.py:892, in MatFile5Writer.put_variables(self, mdict, write_header)
#     890     self.file_stream.write(out_str)
#     891 else:  # not compressing
# --> 892     self._matrix_writer.write_top(var, name.encode('latin1'), is_global)
#
# File c:\Users\Gil Beirao\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\io\matlab\_mio5.py:633, in VarWriter5.write_top(self, arr, name, is_global)
#     631 self._var_name = name
#     632 # write the header and data
# --> 633 self.write(arr)
#
# File c:\Users\Gil Beirao\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\io\matlab\_mio5.py:662, in VarWriter5.write(self, arr)
#     660     self.write_empty_struct()
#     661 elif narr.dtype.fields:  # struct array
# --> 662     self.write_struct(narr)
#     663 elif narr.dtype.hasobject:  # cell array
#     664     self.write_cells(narr)
#
# File c:\Users\Gil Beirao\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\io\matlab\_mio5.py:781, in VarWriter5.write_struct(self, arr)
#     778 def write_struct(self, arr):
#     779     self.write_header(matdims(arr, self.oned_as),
#     780                       mxSTRUCT_CLASS)
# --> 781     self._write_items(arr)
#
# File c:\Users\Gil Beirao\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\io\matlab\_mio5.py:798, in VarWriter5._write_items(self, arr)
#     796 for el in A:
#     797     for f in fieldnames:
# --> 798         self.write(el[f])
#
# File c:\Users\Gil Beirao\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\io\matlab\_mio5.py:653, in VarWriter5.write(self, arr)
#     651 narr = to_writeable(arr)
#     652 if narr is None:
# --> 653     raise TypeError('Could not convert %s (type %s) to array'
#     654                     % (arr, type(arr)))
#     655 if isinstance(narr, MatlabObject):
#     656     self.write_object(narr)
#
# TypeError: Could not convert None (type <class 'NoneType'>) to array
