# %% [markdown]
# # Text analysis

# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
from natsort import natsorted
import re
import plotly.graph_objs as go
from plotly.offline import iplot

np.set_printoptions(threshold=sys.maxsize)
# Load the pickle file into a DataFrame
data = pd.read_pickle('ad-chega.pkl')

# Total debate time in minutes
total_debate_time = 40

# %%
#The Object deteection column 

countPessoa = 0
countTie = 0
countbottle = 0
countTv = 0
countWine = 0
countUmbrella = 0
countTrain = 0
countBowl = 0
countTable = 0
countChair = 0
countBooks = 0

unique_objects = set()

for i in range(0,2367):
        
        Data_objects = np.array(data.iloc[i,1])
        
        for j in range(0, len(Data_objects)):
               
               unique_objects.add(Data_objects[j][4])

               if Data_objects[j][4] == 'person':
                    countPessoa += 1
               elif Data_objects[j][4] == 'tie':
                    countTie += 1
               elif Data_objects[j][4] == 'bottle':
                    countbottle += 1
               elif Data_objects[j][4] == 'tv':
                    countTv += 1
               elif Data_objects[j][4] == 'wine glass':
                    countWine += 1
               elif Data_objects[j][4] == 'umbrella':
                    countUmbrella += 1
               elif Data_objects[j][4] == 'train':
                    countTrain += 1
               elif Data_objects[j][4] == 'bowl':
                    countBowl += 1
               elif Data_objects[j][4] == 'dining table':
                    countTable += 1
               elif Data_objects[j][4] == 'chair':
                    countChair += 1
               elif Data_objects[j][4] == 'book':
                    countBooks += 1

# %%
#Analyse and clean text


def time_str_to_float(time_str):
    # Split the string on the period to separate minutes and seconds
    minutes_str, seconds_str = time_str.split('.')
    # Convert strings to integer and float, respectively
    minutes = int(minutes_str)
    seconds = float(seconds_str)
    # Convert seconds to a fraction of a minute
    seconds_fraction = seconds / 60.0
    # Return as float
    return minutes + seconds_fraction

def clean_time_string(t):
   
    return t.replace('I', '1').replace('O', '0').replace('l', '1').replace('o', '0')

#first lets order the images

data = data.sort_values(by='filename')


pd.set_option('display.max_rows', None)

pattern_mo = r'\bMO\w+\b'

pattern_v = r'\bv\w+\b'

count = 0

Used_list = []


# Iterate over the rows of the DataFrame starting from index 73
for i in range(73, len(data)):

    # Extract the list from the specified column
    data_inside = data.iloc[i, 4]

    # Iterate over each string in the list
    for j in range(len(data_inside)):

        # Check if the pattern matches the string
        if re.search(pattern_mo, data_inside[j]):

            # If pattern is found, extract the current string and the next three strings
            desired_info = data_inside[j:j+4]  # Extract the next three strings

            # Translate "MO..." to "Montenegro" and "v..." to "Ventura"
            translated_info = []
            for item in desired_info:
                if re.match(pattern_mo, item):
                    translated_info.append("Montenegro")
                elif re.match(pattern_v, item):
                    translated_info.append("Ventura")
                else:
                    translated_info.append(item)

            # Append the translated_info to Used_list
            Used_list.append(translated_info)


# Filter out lists with exactly 4 objects
Used_list = [desired_info for desired_info in Used_list if len(desired_info) == 4]


# Initialize arrays to store Montenegro and Ventura times
montenegro_times = []
ventura_times = []

for list in Used_list:
 
    # Get the first two characters
    first_part_m = list[1][:2]

    # Get the last two characters
    second_part_m = list[1][-2:]

    first_part_v = list[2][:2]

    second_part_v = list[2][-2:]
    
     # Join the Montenegro parts with a period in the middle
    montenegro_time = f"{first_part_m}.{second_part_m}"

    # Join the Ventura parts with a period in the middle
    ventura_time = f"{first_part_v}.{second_part_v}"
    
    # Append the times to the arrays
    montenegro_times.append(montenegro_time)
    ventura_times.append(ventura_time)

# Apply cleaning to time strings
montenegro_times_cleaned = [clean_time_string(time) for time in montenegro_times]
ventura_times_cleaned = [clean_time_string(time) for time in ventura_times]

# Filter out any strings that contain 'VE'
montenegro_times_filtered = [time for time in montenegro_times_cleaned if 'VE' not in time]
ventura_times_filtered = [time for time in ventura_times_cleaned if 'VE' not in time]

# Filter out any strings that contain 'VE'
montenegro_times_filtered2 = [time for time in montenegro_times_filtered if 'AD' not in time]
ventura_times_filtered2 = [time for time in ventura_times_filtered if 'AD' not in time]

# Filter out any strings that contain 'VE'
montenegro_times_filtered3 = [time for time in montenegro_times_filtered2 if 'Ve' not in time]
ventura_times_filtered3 = [time for time in ventura_times_filtered2 if 'Ve' not in time]

# Filter out any strings that contain 'VE'
montenegro_times_filtered4 = [time for time in montenegro_times_filtered3 if 'ª' not in time]
ventura_times_filtered4 = [time for time in ventura_times_filtered3 if 'ª' not in time]

# Filter out any strings that contain 'VE'
montenegro_times_filtered5 = [time for time in montenegro_times_filtered4 if '[2' not in time]
ventura_times_filtered5 = [time for time in ventura_times_filtered4 if '[2' not in time]


# Now attempt the conversion again
montenegro_minutes = [time_str_to_float(time) for time in montenegro_times_filtered5]
ventura_minutes = [time_str_to_float(time) for time in ventura_times_filtered5]

# Assuming montenegro_minutes and ventura_minutes are available and contain speaking time in minutes for each speech turn.

total_debate_time = 40  # Total time for the debate in minutes
total_speech_turns = max(len(montenegro_minutes), len(ventura_minutes))

# Calculate the average duration per speech turn in minutes
average_duration_per_turn = total_debate_time / total_speech_turns

# Generate x-axis values corresponding to the actual time in minutes
x_axis_time = [i * average_duration_per_turn for i in range(total_speech_turns)]

plt.figure(figsize=(15, 10))  # Increase figure size for better visibility

# Use the same x-axis for both speakers, assuming both arrays cover the entire debate duration
plt.plot(x_axis_time[:len(montenegro_minutes)], montenegro_minutes, label='Montenegro', linewidth=2.5)
plt.plot(x_axis_time[:len(ventura_minutes)], ventura_minutes, label='Ventura', linewidth=2.5)

# Add shaded area between the lines where applicable
plt.fill_between(x_axis_time[:min(len(montenegro_minutes), len(ventura_minutes))], 
                 montenegro_minutes[:min(len(montenegro_minutes), len(ventura_minutes))], 
                 ventura_minutes[:min(len(montenegro_minutes), len(ventura_minutes))], color='grey', alpha=0.3)

# Add labels and title with more description
plt.xlabel('Time (minutes)')
plt.ylabel('Speaking Time (minutes)')
plt.title('Speaking Time Evolution for Montenegro and Ventura')

# Enhance the legend
plt.legend(loc='upper left', fontsize='large', frameon=True, shadow=True)

# Show the plot with an enhanced grid for better readability and axis range adjustment
plt.grid(True, linestyle='--', alpha=0.7)  # Enhanced grid visibility
plt.xlim(left=0, right=total_debate_time)  # Adjusted for the total duration of the debate
plt.ylim(bottom=0, top=max(max(montenegro_minutes), max(ventura_minutes)) + 1)  # Set dynamic upper limit based on max speaking time

plt.tight_layout()  # Adjust the padding between and around subplots
plt.show()

# %% [markdown]
# Now Lets do the same for the other debates. Lets use a calmer debate, like BE and Livre  --> DOESN´T HAVE TEXT!
#                                                                            BE and PAN ---> NO TEXT!
#
#
# JUST THE DEBATES ON RTP HAVE THE TIME!!!!

# %% [markdown]
# LIVRE - PS

# %%
# Load the pickle file into a DataFrame
data = pd.read_pickle('livre-ps.pkl')

print(data.iloc[:, 4])
# Out:
# 0           [523, [2924, NUNEBRQTOS, 00:000O:54, TARHRES]
# 1             [826241, NUNEBRQTOS, 11:40, 11.33, TARHRES]
# 2          [23, 82624, NUNEBRQTOS, 03.51, 03.49, TARHRES]
# 3       [=3, ª, NUNEBRPTOS, 01.35, 01.28, TARHRES, 9, ...
# 4         [3, 0 ), 2124, NUNEBRQTOS, 00:000O:12, TARURES]
# 5             [3, 2124, NUNEBROTOS, 00:00IOO:19, TARHRES]
# 6       [0), RUI TAVARES, Livre, 224, NUNPEBRQTOS, 13....
# 7          [0)7, NUNEBRQTOS, 10.38, 09.42, TARURES, 2624]
# 8         [=3, 826241, NUNEBRPTOS, 13.51, 13.04, TARHRES]
# 9                [=3, n, DIREÇÃO DE INFORMAÇÃO, RTP 2024]
# 10          [[2624, NUNSBRPTOS, 05,45, 05.26, TARHRES, 2]
# 11       [=3, 1, NUNEBRBTOS, 06.44, 05.27, TARHRES, 2924]
# 12          [9), 2124, NUNEBRQTOS, 08.22, 07-45, TARHRES]
# 13          [1, {2124, NUNEBRQTOS, 10.38, 10.01, TARHRES]
# 14          [0), 2124, NUNEBRQTOS, 13.35, 12.09, TARHRES]
# 15         [=3, 82624, NUNEBRBTOS, 11-48, 11.33, TARURES]
# 16       [3, 0), 2124, NUNEBRQTOS, 10.38, 09.34, TARHRES]
# 17        [728, [2524, NUNEBRQTOS, 03.51, 04:07, TARHRES]
# 18      [9, #, 2174, PEDRO, 07.13, 07:00, RUI, NUNO SA...
# 19      [=3, 1, [, NUNEBRQTOS, 01.27, 01.28, TARHRES, ...
# 20      [=3, ª, NUNEBRRTOS, 12.46, 11.33, TARHRES, 9, ...
# 21        [3, [29241 , NUNSBRBTOS, 03.51, 02.01, TARHRES]
# 22       [=3, ª, NUNEBROTOS, 03.05, 01.28, TARHRES, 2524]
# 23           [2124, NUNEBRQTOS, 10.38, 09.52, TARURES, 7]
# 24       [528, 1, NUNEBRQTOS, 1131, 11.33, TARHRES, 2924]
# 25                        [[2624, ESLATIU, [, [2424, 61l]
# 26      [523, ª, NUNEBRQTOS, 01:03, 01.28, TARHRES, 9,...
# 27         [0), NUNEBRQTOS, 13.35, 12.18, TARURES, 28241]
# 28          [9), 2424, NUNEBROTOS, 08.22, 07.15, TARHRES]
# 29       [=3, ª, 2624, NUNEBRQTOS, 08.07, 07.13, TARURES]
# 30              [8212, NUNEBRBTOS, 03.04, 01.28, TARHRES]
# 31       [ª, NUNPEBRBTOS, 12.40, 11.33, TARHRES, A, 2424]
# 32      [=3, ª, NUNEBRRTOS, 08.42, 09.27, TARHRES, 9, ...
# 33         [=3, [2924, NUNEBRQTOS, 03.51, 02.42, TARHRES]
# 34      [=3, 1, #, 2624, NUNEBROTOS, 13.06, 11.33, TAR...
# 35          [9, {2124, NUNGBRPTOS, 08.22, 09.18, TARURES]
# 36        [=73, [2424, NUNEBROTOS, 10:57, 11.33, TARHRES]
# 37       [=3, 1, NUNSBRPTOS, 14:25, 13.10, TARHRES, 2924]
# 38           [2124, NUNEBROTOS, 10.38, 09.39, TARURES, 9]
# 39      [3, 1, NUNSBR TOS, 07.13, 07.06, TARHRES, 5, 2...
# 40      [=3, 1, 6, 2(24, NUNSBRBTOS, 07.16, 07.13, TAR...
# 41                   [FsLATI, 7, i, 2, 9, P62u, 1,, 2024]
# 42           [3, 2624, NUNEBRQTOS, 07.12, 06.41, TARURES]
# 43         [23, [2924, NUNEBRQTOS, 08.22, 08.43, TARURES]
# 44        [3, 2, 2(24, NUNEBRPTOS, 03.51, 03.21, TARHRES]
# 45        [NUNEBRBTOS, 13.35, 11.37, TARURES, 8, 7, 2824]
# 46         [=23, 8262, NUNEBRQTOS, O1:OO, 01.28, TARURES]
# 47          [9), 2124, NUNEBRQTOS, 08.22, 08.25, TARHRES]
# 48        [3, 2424, NUNGBRPTOS, 08.22, 09.09, TARHRES, ^]
# 49      [33, 9, ª, 2424, NUNEBROTOS, 03.31, 01:28, TAR...
# 50        [3, ª, '262, NUNEBRQTOS, 07.13, 07.04, TARHRES]
# 51           [ª, 2624, NUNEBRQTOS, 03.04, 01.28, TARURES]
# 52         [=3, 1, NUNEBRQTOS, 00:000O:42, TARURES, 2124]
# 53        [23, 1, 2424, NUNEBRBTOS, 10.40, 1132, TARURES]
# 54          [23, NUNEBRQTOS, 08.22, 09.08, TARHRES, 2624]
# 55        [0 ,, 2124, NUNPEBRQTOS, 08.22, 08.35, TARURES]
# 56      [=3, ª, NUNEBRPTOS, 13.01, 11.33, TARHRES, 9, ...
# 57            [2, 224, NUNEBRQTOS, 03.51, 01.28, TARHRES]
# 58         [=3, 82524, NUNEBROTOS, OO:OO, 01.28, TARHRES]
# 59       [3, 0), 2024, NUNEBRQTOS, 03.51, 03.33, TARHRES]
# 60       [73, ª, 2624, NUNEBROTOS, 12.05, 11.33, TARHRES]
# 61        [3, 2424, NUNEBRQTOS, 10.38, 10.41, TARHRES, 1]
# 62      [23, PEDRO NUNO SANTOS, PS, 1, NUNEBRBTOS, 12....
# 63              [2124, NUNEBRQTOS, 13.35, 12.48, TARURES]
# 64      [=3, {2624, NUNEBROTOS, 04807, 05.26, TARHRES, 9]
# 65      [=3, 1, ª, NUNEBRBTOS, 03.20, 01.28, TARHRES, ...
# 66      [31, 0), 2124, NUNEBRQTOS, 10.38, 10.20, TARHRES]
# 67       [=3, 1, NUNEBRPTOS, 01.30, 01.28, TARHRES, 2924]
# 68        [23, 82524, NUNPEBRQTOS, 08.22, 07.13, TARURES]
# 69         [723, 8262, NUNEBRQTOS, 03.55, 05.13, TARHRES]
# 70         [0), 2124, NUNPEBRQTOS, 13.35, 12.05, TARHRES]
# 71      [23, 9, 9, 224, NUNEBRQTOS, OO:OO, 01.23, TARH...
# 72         [=3, 82624, NUNSBROTOS, 08.39, 09.27, TARHRES]
# 73              [2524, NUNEBROTOS, 09.21, 09.27, TARURES]
# 74      [=3, ª, NUNEBRPTOS, 13.03, 11.33, TARHRES, 9, ...
# 75           [2), 2124, NUNEBROTOS, 03.51, 0415, TARHRES]
# 76        [23, 726241, NUNEBRPTOS, 06.15, 05.26, TARHRES]
# 77              [2124, NUNEBROTOS, 07.12, 06.45, TARHRES]
# 78          [73, 8217, NUNEBRQTOS, 03.45, 01.28, TARURES]
# 79           [7, 2424, NUNEBRRTOS, 07.12, 06.29, TARHRES]
# 80         [3, 824241, NUNEBRPTOS, 03.51, 01.52, TARURES]
# 81         [23, 82524, NUNEBRQTOS, 13.15, 11.33, TARHRES]
# 82                                                 [2(24]
# 83         [2), 72424, NUNEBRQTOS, 07.12, 06.34, TARHRES]
# 84             [8, 2(24, NUNEBROTOS, 00:000O:15, TARURES]
# 85           [0, 2124, NUNEBRQTOS, 08.22, 09.11, TARYRES]
# 86              [2624, NUNEBRQTOS, 09.41, 09.27, TARHRES]
# 87             [82624, NUNSBRBTOS, 03.40, 01.28, TARHRES]
# 88           [3, 8212, NUNEBRQTOS, 04834, 05.26, TARHRES]
# 89        [9, 8, 2424, NUNEBROTOS, 07.21, 07.13, TARYRES]
# 90       [3, 5), 2624, NUNEBRQTOS, 08.22, 07.27, TARYRES]
# 91        [3, 1, NUNEBRPTOS, 03.51, 02.50, TARHRES, 2924]
# 92         [=3, [2924, NUNEBRQTOS, 03.51, 02.39, TARURES]
# 93         [=3, 82524, NUNEBROTOS, 05.37, 05.26, TARHRES]
# 94         [0), NUNEBROTOS, 13.35, 12.28, TARHRES, 28241]
# 95         [=3, 82624, NUNEBROTOS, 05.38, 05.26, TARHRES]
# 96         [23, {2624, NUNEBRRTOS, 05.18, 05.26, TARURES]
# 97      [=3, 82524, NUNEBRRTOS, 13.07, 11.33, TARHRES, 9]
# 98      [3, 9 _, 2(24, NUNEBRQTOS, 03.51, 04:43, TARURES]
# 99       [=3, 1, NUNEBRQTOS, OO:OO, 01.28, TARHRES, 2524]
# 100     [=3, 1, NUNSBRBTOS, 03.13, 01.28, TARHRES, 9, ...
# 101                                   [3, lInas, ª, 2924]
# 102     [=3, 7, ª, NUNEBROTOS, 02.35, 01.28, TARHRES, ...
# 103          [0), 224, NUNEBRBTOS, 03.51, 01.42, TARHRES]
# 104          [1, NUNEBRQTOS, 05:05, 05.26, TARHRES, 2624]
# 105        [523, 2624, NUNEBRQTOS, 13.35, 12.34, TARHRES]
# 106     [3, 244, 2, 2924, NUNEBRQTOS, 03.51, 0424, TAR...
# 107     [=3, ª, NUNEBRQTOS, 01.45, 01.28, TARHRES, 9, ...
# 108                       [3, DEBATE, 2424, LEGISLATIVAS]
# 109      [=3, ª, NUNEBROTOS, 13.40, 13.02, TARHRES, 2924]
# 110          [0, 2124, NUNEBRQTOS, 13.35, 12.33, TARHRES]
# 111          [1, 2424, NUNEBRBTOS, 06.45, 05.27, TARURES]
# 112     [=3, ª, NUNEBRPTOS, 09.23, 09.27, TARHRES, 9, ...
# 113         [0), NUNEBRBTOS, 13.35, 1221, TARHRES, 20241]
# 114      [73, ª, NUNEBRQTOS, 03.53, 05.02, TARHRES, 2924]
# 115     [=3, [2624, NUNEBROTOS, 07.43, 07.13, TARHRES, 9]
# 116      [3, 24, 2624, NUNGBRPTOS, 03.51, 03.38, TARHRES]
# 117       [=3, [29241, NUNEBRPTOS, 03.51, 02.09, TARURES]
# 118          [, 21241, NUNGBRRTOS, 12.03, 11.33, TARHRES]
# 119          [2, 2424, NUNEBRQTOS, OO:OO, 01.25, TARHRES]
# 120          [1, 2424, NUNEBRQTOS, 08.22, 08:11, TARHRES]
# 121     [=3, ª, NUNEBRRTOS, 03.55, 05.26, TARHRES, 9, ...
# 122        [23, [2524, NUNEBRQTOS, 08.22, 08.42, TARHRES]
# 123         [=3, NUNEBR TOS, 10.40, 11:29, TARHRES, 2924]
# 124                              [FSLATI, 6, [, 820, 02u]
# 125         [31, 2124, NUNEBROTOS, 06.25, 05.27, TARHRES]
# 126         [3, 72424, NUNGBROTOS, 07.12, 06.46, TARHRES]
# 127     [=3, {2624, NUNEBROTOS, 01.34, 01.28, TARHRES, 9]
# 128      [=3, 1, NUNEBRRTOS, 13.02, 11.33, TARHRES, 2924]
# 129     [=3, 7, ª, NUNEBRBTOS, 02.51, 01.28, TARHRES, ...
# 130         [0), 2424, NUNEBROTOS, 08.22, 09.12, TARURES]
# 131         [3, [2624, NUNEBRQTOS, 03.51, 01.28, TARHRES]
# 132      [=3, ª, NUNEBROTOS, 03.27, 01.28, TARHRES, 2924]
# 133            [[2624, NUNEBRPTOS, 11:16, 11.33, TARHRES]
# 134      [23, [, 2424, NUNEBRBTOS, 01:17, 01.28, TARHRES]
# 135        [=23, 8262, NUNEBRQTOS, 01:04, 01.28, TARURES]
# 136      [@, 2424, NUNEBRPTOS, 07.12, 06.51, TARURES, LA]
# 137     [=23, 2, 2124, NUNEBRQTOS, 11:13, 11.33, TARURES]
# 138        [3, 826241, NUNEBRQTOS, 07-02, 06.03, TARURES]
# 139        [73, [2624, NUNSBROTOS, 03.51, 02.11, TARURES]
# 140           [3, 262, NUNEBRQTOS, 06.21, 05.27, TARHRES]
# 141          [ª, NUNEBRQTOS, 09.37, 09.27, TARHRES, 2(24]
# 142          [ª, 2124, NUNEBRRTOS, 06.59, 05.58, TARHRES]
# 143     [224, FSLATI, [, 9, 5, 2424, NUNEBRQTOS, 07-16...
# 144      [=3, 1, NUNEBRRTOS, 08.46, 09.27, TARHRES, 2924]
# 145       [3, 0, 2124, NUNEBRQTOS, 10.38, 10.29, TARHRES]
# 146         [17, 2124, NUNEBRQTOS, 07.12, 06.26, TARHRES]
# 147       [0/, NUNPEBRQTOS, 13.35, 12.29, TARURES, 20241]
# 148     [31, 2), 2024, NUNEBRRTOS, 07.12, 06.32, TARHRES]
# 149      [3, {2124, NUNEBROTOS, 08.22, 09.13, TARHRES, 5]
# 150     [=3, 24, ESLAIVAS, [2624, NUNEBRQTOS, 02.27, 0...
# 151     [=3, , #, 2624, NUNEBRBTOS, 10.38, 10.53, TARH...
# 152          [8, 2624, NUNEBROTOS, 06.45, 05.37, TARURES]
# 153        [=3, 82524, NUNEBRBTOS, OO:OO, 01:03, TARHRES]
# 154         [23, 2(24, NUNEBROTOS, 07.13, 06.54, TARYRES]
# 155                                         [31, 1, 2424]
# 156          [1, 2424, NUNEBROTOS, 10.34, 09.29, TARURES]
# 157        [=3, 82624, NUNEBRQTOS, 03.51, 04:06, TARHRES]
# 158       [3, 1, NUNEBRQTOS, 00.23, 01.28, TARHRES, 2924]
# 159     [=3, 1, #, NUNEBRPTOS, 04:O1, 05.26, TARHRES, ...
# 160     [53, HM, ª, NUNEBRQTOS, 07:06, 06.07, TARHRES,...
# 161     [=3, ª, NUNEBROTOS, 08.55, 09.27, TARHRES, 9, ...
# 162                             [HAIR, RUI CANENTO SALON]
# 163      [=3, ª, 2624, NUNSBROTOS, 06:00, 05.26, TARHRES]
# 164      [24, 2424, NUNEBRQTOS, 03.51, 04-12, TARYRES, 7]
# 165     [23, ª, NUNEBRQTOS, 10:55, 11:.33, TARHRES, 2{24]
# 166       [73, 820, NUNEBRQTOS, 13.35, 12.34, TARURES, =]
# 167     [23, 12, PEDRO NUNO SANTOS, PS, 1, NUNEBRQTOS,...
# 168     [=3, 9, =, ª, NUNEBROTOS, 02.52, 01.28, TARURE...
# 169     [=3, {2624, NUNEBROTOS, 03.55, 05.26, TARURES, 9]
# 170          [2, NUNEBROTOS, 08.22, 08.50, TARURES, 2924]
# 171        [=3, 82624, NUNEBRBTOS, 11l1, 11:*33, TARHRES]
# 172       [23, {26241, NUNSBRRTOS, 10.38, 11.01, TARHRES]
# 173     [23, ª, NUNSBRBTOS, 04:09, 05.26, TARHRES, 9, ...
# 174        [=23, 8262, NUNEBRQTOS, 00:55, 01.28, TARHRES]
# 175          [=3, [2924, NUNEBRQTOS, 00:000O:58, TARHRES]
# 176     [=3, 1, 1, NUNEBROTOS, 02.27, 01.28, TARHRES, ...
# 177     [=3, 9, #, NUNEBROTOS, 11:51, 11.33, TARHRES, ...
# 178                   [ESLATIVA, T, ª, 9, 122, p624, 7,|]
# 179     [=3, 5i, ª, 2524, NUNEBRQTOS, 02.27, 01.28, TA...
# 180      [3, 1, NUNPEBRQTOS, 03.54, 05.10, TARHRES, 2424]
# 181     [3, ª, NUNEBRBTOS, 04:44, 05.26, TARHRES, 5, 2...
# 182     [=3, ª, NUNEBRPTOS, 08.06, 07.13, TARHRES, 9, ...
# 183      [=3, 1, NUNEBRQTOS, 01.31, 01.28, TARHRES, 2924]
# 184        [523, 8212, NUNEBRQTOS, 04:56, 05.26, TARHRES]
# 185      [=3, 1, NUNEBROTOS, 14:19, 13.06, TARHRES, 2624]
# 186      [23, 9, 2424, NUNEBRBTOS, 04:43, 05.26, TARURES]
# 187              [2124, ESLATIVAS, to: ,, 1, 9, 2v, 2624]
# 188        [23, 82624, NUNEBRQTOS, 13.38, 13.02, TARHRES]
# 189     [23, {2624, NUNEBRQTOS, 07-16, 07.13, TARHRES, 9]
# 190      [3, 9), 2424, NUNEBROTOS, 08.22, 09.26, TARHRES]
# 191      [=3, ª, NUNEBROTOS, 02.18, 01.28, TARHRES, 2924]
# 192                                        [[GeCskehnqee]
# 193          [0, 2124, NUNEBRQTOS, 13.35, 12.40, TARHRES]
# 194     [=3, 1, ª, NUNSBR TOS, 03.14, 01.28, TARHRES, ...
# 195       [3, 2, 2124, NUNEBRBTOS, 03.51, 04-28, TARURES]
# 196      [23, ª, 2524, NUNEBRBTOS, 07.53, 07.13, TARHRES]
# 197            [82624, NUNEBRQTOS, 03.43, 01.28, TARHRES]
# 198       [3, 2424, NUNGBRQTOS, 08.22, 07.36, TARURES, 0]
# 199            [72424, NUNEBROTOS, 07.12, 06.44, TARYRES]
# 200     [31, 72424, NUNEBRQTOS, 07.12, 06.18, TARHRES, 5]
# 201      [=3, 1, NUNEBRQTOS, 02.06, 01.28, TARURES, 2924]
# 202      [=3, 1, 2424, NUNEBRBTOS, 04-24, 05.26, TARHRES]
# 203     [73, 1, PEDRO, 09.34, 09.27, RUI, NUNO SANTOS,...
# 204      [=3, 1, NUNEBROTOS, O2:01, 01.28, TARHRES, 2924]
# 205     [3, 0 , {2124, NUNEBRPTOS, 10.38, 10.09, TARURES]
# 206                                                    []
# 207        [3, ª, 262, NUNEBRQTOS, 10.08, 09.29, TARHRES]
# 208        [523, 8262, NUNEBR TOS, 05.03, 05.26, TARHRES]
# 209          [2624, NUNEBRQTOS, 08.50, 09.27, TARHRES, 9]
# 210     [1/, iio, #Mn, 2624, NUNPEBRQTOS, 07.30, 07.13...
# 211          [2, 2124, NUNEBRPTOS, 12.32, 11.33, TARHRES]
# 212       [523, 82624, NUNEBROTOS, OO:OO, 01:04, TARHRES]
# 213      [=3, ª, NUNEBRBTOS, 13.41, 13.02, TARHRES, 2924]
# 214     [23, [25241, NUNEBRQTOS, 13.22, 11.33, TARHRES...
# 215     [=23, 0, NUNPEBRQTOS, 00:41, 01.28, TARHRES, 2...
# 216     [=3, 82624, NUNEBRPTOS, 04-13, 05.26, TARURES, 9]
# 217       [3, 9, 2624, NUNEBRQTOS, 08.22, 07.32, TARHRES]
# 218                                        [=73, 1, 2924]
# 219     [73, , 1, NUNEBRPTOS, 03.10, 01.28, TARHRES, 2...
# 220           [[29248, NUNSBRBTOS, 07:00, 06:01, TARHRES]
# 221        [=3, 82524, NUNEBROTOS, 03.58, 05.26, TARURES]
# 222          [9, 2624, NUNEBR TOS, 10.53, 11.33, TARHRES]
# 223         [21241, NUNEBRBTOS, 08.22, 07.47, TARURES, 2]
# 224     [=3, {2624, NUNEBROTOS, 08.59, 09.27, TARHRES, 9]
# 225     [=3, {2624, NUNEBRPTOS, 11:58, 11.33, TARHRES, 9]
# 226     [=3, 7, 1, NUNPEBRQTOS, 03.17, 01.28, TARURES,...
# 227       [573, {2624, NUNEBRPTOS, 09.33, 09.27, TARHRES]
# 228      [=3, 8262, NUNEBRPTOS, 04:55, 05.26, TARHRES, 9]
# 229     [=3, 9, {2624, NUNEBROTOS, OO:02, 01.28, TARUR...
# 230          [3, 8242, NUNEBROTOS, 03.55, 05.20, TARURES]
# 231     [23, ª, NUNEBRBTOS, 01:40, 01.28, TARHRES, 9, ...
# 232             [2124, NUNEBRQTOS, 03.51, 01.33, TARHRES]
# 233             [NUNEBRBTOS, 14*33, 13.10, TARHRES, 2424]
# 234     [=3, ª, NUNEBROTOS, 02.10, 01.28, TARHRES, 9, ...
# 235        [23, 72424, NUNEBRBTOS, 09.28, 09.27, TARURES]
# 236       [3, 1, NUNEBRRTOS, 13.25, 11.33, TARHRES, 2924]
# 237                ['2124, ESLATIVAS, 4 <, 1, 9, 1, 2924]
# 238      [=3, 82624, NUNEBRQTOS, OO:OO, 0105, TARHRES, 9]
# 239         [3, 82424, NUNEBRBTOS, 03.53, 05.04, TARHRES]
# 240           [[2(241, NUNEBRQTOS, 08.05, 07.13, TARURES]
# 241      [23, 9, 2124, NUNEBROTOS, OO:OO, 01.22, TARURES]
# 242                   [Pt2r, uSLATIS, i, ª, 9, Ain, 2646]
# 243        [=3, 82524, NUNEBRBTOS, 08.23, 09.27, TARHRES]
# 244             [2624, NUNEBRRTOS, 04:27, 05.26, TARHRES]
# 245        [=3, 82524, NUNEBROTOS, 01.52, 01.28, TARURES]
# 246         [0, 2124, NUNPEBRBTOS, 10.38, 09.38, TARHRES]
# 247         [0), 2424, NUNEBROTOS, 08.22, 08.27, TARURES]
# 248        [23, {2124, NUNEBRQTOS, 03.55, 05.26, TARHRES]
# 249     [73, ª, NUNEBROTOS, 04:02, 05.26, TARURES, 9, ...
# 250        [23, {2624, NUNSBROTOS, 12.00, 11.33, TARHRES]
# 251        [3, 822, NUNEBRPTOS, 04833, 05.26, TARURES, 9]
# 252        [=3, [2624, NUNEBROTOS, 07.42, 07.13, TARHRES]
# 253        [9), 52124, NUNEBRBTOS, 08.22, 07-49, TARURES]
# 254     [=3, {2624, NUNEBRPTOS, 12.10, 11.33, TARHRES, 9]
# 255      [=3, ª, NUNEBRQTOS, 06.41, 05.27, TARURES, 2424]
# 256     [23, PEDRO NUNO SANTOS, PS, ª, NUNEBROTOS, 12....
# 257              [2la, NUNEBRQTOS, 08.22, 07.17, TARHRES]
# 258     [=3, ª, {2424, NUNSBRBTOS, 12.07, 11.33, TARURES]
# 259     [=3, 9, ª, 2424, NUNEBRPTOS, 03.21, 01.28, TAR...
# 260       [23, ª, NUNEBRQTOS, 04836, 05.26, TARURES, 212]
# 261         [3, 82424, NUNEBRPTOS, 14:01, 13.04, TARHRES]
# 262       [3, 1, NUNEBRQTOS, 10.07, 09.29, TARHRES, 2124]
# 263      [3, 2424, NUNEBROTOS, 10.38, 10.45, TARHRES, 5)]
# 264         [0), NUNEBROTOS, 13.35, 11.45, TARHRES, 2024]
# 265                                                  [=3]
# 266      [=3, ª, 2424, NUNEBRQTOS, 10.29, 09.29, TARHRES]
# 267          [2124, NUNEBRQTOS, 13.35, 12.37, TARURES, C]
# 268     [3, RUI TAVARES, Livre, 2124, NUNEBROTOS, OO:O...
# 269          [9, 2124, NUNEBRQTOS, 07.32, 07.13, TARYRES]
# 270                          [23, DE, 2424, LEGISLATIVAS]
# 271         [9), 2124, NUNEBROTOS, 08.22, 08.24, TARHRES]
# 272       [=28, [2524, NUNEBRQTOS, 11-08, 11.33, TARURES]
# 273         [0), 2124, NUNEBRQTOS, 13.35, 12.06, TARURES]
# 274     [53, 9/7, 2624, NUNEBRBTOS, 08.22, 07.30, TARH...
# 275          [9), 2124, NUNEBRQTOS, OO:OO, 0124, TARURES]
# 276     [=3, 1, {2624, NUNEBRPTOS, 06:11, 05.26, TARHR...
# 277         [0), 2124, NUNEBRQTOS, 13.35, 12.07, TARURES]
# 278     [=3, {2624, NUNEBRQTOS, 08.45, 09.27, TARHRES, 9]
# 279     [=3, 82524, NUNEBRPTOS, 05.36, 05.26, TARHRES, 9]
# 280     [=3, 1, #, NUNEBRBTOS, 13.30, 11.33, TARHRES, ...
# 281         [3, [2124, NUNEBR TOS, 03.53, 05.07, TARHRES]
# 282        [31, 8252 , NUNEBRQTOS, 03.51, 02.28, TARURES]
# 283     [=3, ª, NUNEBRQTOS, 13.35, 13.02, TARHRES, 9, ...
# 284     [523, 1, NUNEBRQTOS, 03.55, 05.17, TARURES, 2924]
# 285        [23, 1, NUNEBRPTOS, 0O:00OO:40, TARURES, 2924]
# 286      [=3, 1, NUNEBRBTOS, 03.51, 03.27, TARHRES, 2924]
# 287        [723, 8262, NUNEBRQTOS, 04-54, 05.26, TARURES]
# 288       [3, [, 2624, NUNEBROTOS, 03.51, 04-20, TARURES]
# 289     [=3, =, 1, NUNEBROTOS, 02.04, 01.28, TARURES, ...
# 290       [2, ª, NUNEBRQTOS, 09.36, 09.27, TARHRES, 2624]
# 291         [=3, '224, NUNEBRBTOS, 13.35, 12.34, TARHRES]
# 292        [73, [2924, NUNSBROTOS, 14:02, 13.04, TARHRES]
# 293      [=3, 1, NUNEBROTOS, 00.24, 01.28, TARHRES, 2924]
# 294      [=3, ª, NUNEBRQTOS, 13.43, 13.02, TARHRES, 2924]
# 295         [1, 22, NUNEBRQTOS, 08.22, 07.13, TARHRES, T]
# 296             [2424, NUNEBROTOS, 10.38, 09.29, TARHRES]
# 297      [3, 2), 2024, NUNEBRRTOS, 07.12, 06.33, TARYRES]
# 298       [3, 2424, NUNEBRQTOS, 10.38, 10.37, TARURES, 5]
# 299         [3, [2924, NUNEBRBTOS, 13.59, 13.04, TARHRES]
# 300     [23, 2, PEDRO, 11.48, 11.33, RUI, 9, NUNO SANT...
# 301        [23, [2624, NUNEBRQTOS, 09.48, 09.29, TARHRES]
# 302     [523, 1, 2124, NUNEBRQTOS, 07-45, 07.13, TARURES]
# 303      [73, 1, NUNSBRPTOS, 03.51, 03.56, TARHRES, 2924]
# 304       [73, 1, NUNEBRQTOS, OO:OO, 0128, TARHRES, 2924]
# 305     [3, 9), 91, 2624, NUNEBRQTOS, 08.22, 08.18, TA...
# 306     [523, 1, NUNEBRQTOS, 08.22, 09.0O, TARHRES, 2924]
# 307       [=3, 1, NUNEBROTOS, OO:OO, O11O, TARURES, 2924]
# 308     [2124, FSLATIVAS, i, ª, JOÃO ADELINO FARIA, 9,...
# 309     [3, 52124, NUNEBROTOS, 10.38, 09.35, TARHRES, 5y]
# 310         [31, 2124, NUNEBRBTOS, 14831, 13.10, TARURES]
# 311        [23, NUNPEBRBTOS, 13.35, 12.34, TARHRES, 2624]
# 312         [23, 8212, NUNEBRQTOS, 04:40, 05.26, TARHRES]
# 313             [2624, NUNSBRRTOS, 05.43, 05.26, TARHRES]
# 314             [820_, NUNEBRQTOS, 14836, 13.14, TARURES]
# 315         [3, 2124, NUNPEBRBTOS, 10.38, 10.19, TARURES]
# 316     [31, 0), 2024, NUNEBROTOS, 03.51, 01.43, TARURES]
# 317     [723, 2, 2124, NUNEBRQTOS, 03.51, 04.47, TARHRES]
# 318     [=3, 9, NUNEBRQTOS, 03.51, 04:08, TARHRES, "9424]
# 319         [2124, NUNPEBRNTOS, 13.35, 12.27, TARHRES, 5]
# 320     [=3, [2924, NUNEBRQTOS, 05.53, 05.26, TARURES, 9]
# 321      [23, ª, 2424, NUNEBRQTOS, 12.09, 11.33, TARHRES]
# 322              [224, NUNSBR TOS, 13.35, 11*33, TARHRES]
# 323      [=3, 1, NUNEBRPTOS, 03.25, 01.28, TARURES, 2924]
# 324       [523, [2524, NUNEBRQTOS, 03.51, 04:08, TARURES]
# 325         [3, ª, NUNEBRQTOS, 06.36, 05.27, TARHRES, 26]
# 326     [31, ª, NUNEBRPTOS, 09.45, 09.29, TARHRES, 9, ...
# 327     [733, 1, NUNEBRQTOS, 11:21, 11*33, TARHRES, 2424]
# 328        [3, [26241, NUNEBRQTOS, 14-20, 13.06, TARHRES]
# 329        [3, 6, 224, NUNEBRQTOS, 07-59, 07.13, TARURES]
# 330     [=3, ª, [25241, NUNSBR TOS, 07-41, 07.13, TARU...
# 331      [23, 1, NUNEBRQTOS, 03.04, 01.28, TARURES, 2624]
# 332        [73, 82424, NUNEBROTOS, 12.28, 11.33, TARHRES]
# 333                                        [[GeCskehnqee]
# 334                [ALDO, Shop online, ALD O SH OES . PT]
# 335     [=3, ª, NUNEBROTOS, 03.30, 01.28, TARHRES, 9, ...
# 336     [=3, ª, NUNEBRPTOS, 05.20, 05.26, TARHRES, 9, ...
# 337        [23, [2624, NUNGBRPTOS, 10.38, 11.03, TARHRES]
# 338         [23, NUNEBRQTOS, 08.22, 07-41, TARHRES, 212a]
# 339        [23, 82424, NUNEBROTOS, 13.47, 13.04, TARURES]
# 340      [=3, 1, NUNEBROTOS, 00:03, 01.28, TARHRES, 2924]
# 341           [Este programa, teve ajuda, à produção de:]
# 342      [=3, 6, 2424, NUNSBRBTOS, I1:1O, 11.33, TARURES]
# 343        [=3, {2624, NUNEBRBTOS, 06.43, 05.27, TARHRES]
# 344             [2124, NUNEBRQTOS, 13.35, 11.55, TARURES]
# 345      [=3, 9, NUNEBRBTOS, 13.35, 12.34, TARHRES, 2624]
# 346           [ª, 224, NUNEBRQTOS, 06.45, 05.27, TARHRES]
# 347      [3, [2624, NUNSBRBTOS, 07.07, 06.08, TARHRES, 9]
# 348                             [FsLATI, G, 820, 162(, a]
# 349             [2424, NUNEBROTOS, 10.38, 09.29, TARURES]
# 350        [3, 2, 212, NUNEBRBTOS, 06.30, 05.27, TARHRES]
# 351      [=3, 1, NUNSBRPTOS, 13.48, 13.04, TARHRES, 2924]
# 352       [=3, 82624, NUNPEBRPTOS, 03.51, 01.28, TARHRES]
# 353         [3, 26241, NUNEBRPTOS, 08.22, 08.53, TARURES]
# 354     [73, 9, ª, NUNPEBRQTOS, 02.27, 01.28, TARHRES,...
# 355     [528, Fn, 82424, NUNEBROTOS, 1124, 11.33, TARH...
# 356        [=3, 82624, NUNEBROTOS, 07-20, 07.13, TARHRES]
# 357          [1, 2624, NUNEBROTOS, 09.21, 09.27, TARHRES]
# 358     [23, ª, 2424, NUNPEBRQTOS, 08.04, 07.13, TARHRES]
# 359       [3, 5, 2124, NUNEBRPTOS, 13.49, 13.04, TARURES]
# 360         [23, 8262, NUNEBRQTOS, 04838, 05.26, TARURES]
# 361     [3, 2 ), 2624, NUNEBROTOS, 06.45, 05.33, TARURES]
# 362      [=3, ª, 2624, NUNEBRPTOS, 07.50, 07.13, TARHRES]
# 363      [=3, 1, NUNEBRBTOS, 03.51, 02.34, TARURES, 2924]
# 364         [3, {2124, NUNEBRQTOS, 14835, 13.12, TARHRES]
# 365     [=3, 1, #, 2424, NUNEBRBTOS, OO:OO, 01.28, TAR...
# 366          [3, 0, 22, NUNEBRQTOS, 13.35, 1251, TARHRES]
# 367       [2 4, , 224, NUNEBRQTOS, 03.51, 01.28, TARHRES]
# 368     [3, 1, 9, {2124, NUNEBRQTOS, 05.32, 05.26, TAR...
# 369             [2124, NUNEBRQTOS, 10.38, 10.25, TARYRES]
# 370         [3, 82424, NUNEBRQTOS, 08.22, 08.59, TARHRES]
# 371                                            [=3, 2624]
# 372     [23, 9, [, 2624, NUNSBRPTOS, 10.40, 11.33, TAR...
# 373          [3, 8242, NUNSBRBTOS, 06.59, 05.50, TARHRES]
# 374        [3, , 2124, NUNEBRPTOS, 06.49, 05.44, TARURES]
# 375        [As, 82624, NUNEBRBTOS, 05.24, 05.26, TARHRES]
# 376     [=23, 1, NUNEBRRTOS, 01:06, 01.28, TARHRES, 2924]
# 377       [3, 1, NUNEBRBTOS, 07.16, 07:12, TARHRES, 2624]
# 378       [23, 825241, NUNEBRBTOS, 10.38, 11:1O, TARYRES]
# 379     [=23, @, {242 , NUNEBRQTOS, 10:58, 11.33, TARY...
# 380     [31, 2), NUNEBRQTOS, 03.51, 02.58, TARHRES, 2824]
# 381           [9, 224, NUNEBRQTOS, OO:OO, 01.23, TARURES]
# 382      [23, 1, NUNEBRQTOS, 03.53, 05.03, TARYRES, 2624]
# 383     [2(24, FsLATVAS, I, 1, NUNEBRQTOS, 00:00l0O.27...
# 384      [=3, 2, 7224, NUNEBROTOS, 10.40, 11.33, TARHRES]
# 385     [FsLATIAS, I, 5, 2624, PEDRO, 08.22, 07-40, RU...
# 386                                          [3, 1, 2624]
# 387            [[2624, NUNEBRBTOS, 06.59, 05.55, TARHRES]
# 388     [23, {2624, NUNEBROTOS, 08.31, 09.27, TARHRES, 9]
# 389     [23, ª, NUNSBROTOS, OO:OO, 01.28, TARURES, 9, ...
# 390          [9, 2124, NUNGBRPTOS, 08.22, 07.51, TARHRES]
# 391     [=3, 4, NUNEBRQTOS, 03.51, 02.53, TARHRES, 91241]
# 392     [=3, #, NUNEBRBTOS, OO:OO, 01.28, TARHRES, 22424]
# 393     [=3, ª, NUNEBRQTOS, 03.51, 04:49, TARHRES, 9, ...
# 394      [=3, 1, NUNEBRQTOS, 03.51, 02.29, TARURES, 2624]
# 395     [ESLATI, [, 9, 2424, NUNEBRQTOS, 07.16, 07.13,...
# 396     [=3, 1, 82524, NUNEBRQTOS, 02.58, 01.28, TARHRES]
# 397      [=3, 1, NUNEBRRTOS, 13:11, 11.33, TARHRES, 2924]
# 398      [23, ª, NUNEBRQTOS, 06.41, 05.27, TARHRES, 2624]
# 399       [3, 1, NUNEBRQTOS, 14:09, 13.04, TARYRES, 2624]
# 400       [3, 1, NUNEBRPTOS, 03.51, 02.51, TARHRES, 2924]
# 401                             [=3, I257, NuNO, LAVARES]
# 402        [523, 8242, NUNEBRQTOS, 04831, 05.26, TARHRES]
# 403         [0), 2124, NUNEBRQTOS, 13.35, 12.22, TARURES]
# 404        [=3, [2624, NUNEBROTOS, 03.51, 02.22, TARHRES]
# 405       [3, 2(24, NUNEBRBTOS, 08.22, 07.33, TARURES, 9]
# 406       [=3, [25245, NUNEBROTOS, 03.56, 05.26, TARHRES]
# 407       [3, 1, 2624, NUNEBRPTOS, 07.12, 06.21, TARURES]
# 408     [=3, 9, #, NUNEBRQTOS, 08.36, 09.27, TARHRES, ...
# 409          [2124, NUNEBRQTOS, 08.22, 07.52, TARHRES, 2]
# 410     [=3, {2624, NUNEBROTOS, 00:04, 01.28, TARHRES, 9]
# 411         [=3, 1824, NUNEBROTOS, 13.35, 13.00, TARURES]
# 412     [=3, [2624, NUNEBRRTOS, 02.26, 01.28, TARHRES, 9]
# 413     [23, ª, NUNEBRQTOS, 08.12, 07.13, TARURES, 9, ...
# 414     [=3, ª, NUNEBRBTOS, 13.14, 11.33, TARHRES, 9, ...
# 415      [528, 82624, NUNPEBRQTOS, 13.55, 13.04, TARHRES]
# 416     [kSLATIVA, P24, NUNEBRQTOS, 03.51, 03.01, TARH...
# 417        [=3, 82424, NUNEBRRTOS, 00:54, 01.28, TARHRES]
# 418          [9, 2124, NUNEBRRTOS, 08.22, 08.16, TARHRES]
# 419                                       [ROSA&TEIXEIRA]
# 420         [2), 2124, NUNEBRRTOS, 00:00l0O:.27, TARHRES]
# 421       [=3, 825241, NUNEBRBTOS, 10.38, 11.05, TARURES]
# 422         [0), 2024, NUNEBRQTOS, 03.51, 01:41, TARURES]
# 423        [=3, 82524, NUNEBRPTOS, 01:49, 01.28, TARHRES]
# 424     [=3, 882, 1, NUNEBRBTOS, 08.54, 09.27, TARHRES...
# 425            [21241, NUNEBR TOS, 03.51, 01.28, TARHRES]
# 426        [=3, 82624, NUNEBRBTOS, 10.40, 11.33, TARURES]
# 427     [23, {2424, NUNEBRPTOS, 08.22, 07.13, TARHRES, 9]
# 428          [[29241, NUNEBRPTOS, 06:.59, 05.54, TARHRES]
# 429         [NUNEBRPTOS, 10.38, 09.36, TARURES, 2l, 2124]
# 430      [0), 2, 2124, NUNEBRQTOS, 10.38, 10.08, TARURES]
# 431     [81, 1, 05, PEDRO, 08.06, 07.13, RUI, , NUNO S...
# 432      [=3, 1, NUNEBROTOS, 06.54, 05.47, TARHRES, 2924]
# 433     [=3, ª, NUNEBROTOS, 07.38, 07.13, TARHRES, 9, ...
# 434        [=3, 82424, NUNEBRQTOS, 03.51, 02.35, TARHRES]
# 435     [=3, {25241, NUNEBROTOS, 10.36, 09.29, TARHRES...
# 436                                            [2, , 224]
# 437     [31, 9), 2124, NUNEBRQTOS, 03.51, 04834, TARURES]
# 438     [=3, ª, NUNEBRPTOS, 07-19, 07.13, TARHRES, 9, ...
# 439     [23, 91, 1, NUNEBRRTOS, 03.51, 01.37, TARURES,...
# 440                                                 [RTP]
# 441          [1, 2124, NUNEBRQTOS, 03.53, 04*53, TARURES]
# 442                           [[2624, ESLATIVA, [, [2424]
# 443      [23, 1, NUNEBROTOS, 00.27, 01.28, TARHRES, 2924]
# 444      [3, 0), 2124, NUNEBRQTOS, 08.22, 08.12, TARURES]
# 445        [=3, 82624, NUNEBROTOS, 10.40, 11.33, TARHRES]
# 446        [23, [2924, NUNEBRBTOS, 10.40, 11.25, TARHRES]
# 447     [3, 9), {2424, NUNSBROTOS, 08.22, 07.38, TARHRES]
# 448         [3, {2124, NUNSBRPTOS, 04-29, 05.26, TARHRES]
# 449     [73, ª, NUNEBRQTOS, 14836, 13.14, TARHRES, An,...
# 450        [3, [26245, NUNSBROTOS, 03.51, 01.57, TARHRES]
# 451      [=3, 9, NUNEBROTOS, 10.08, 09.29, TARHRES, 7224]
# 452     [=3, , ª, NUNEBRBTOS, 02.24, 0128, TARHRES, 9,...
# 453     [523, 0, {2(24, NUNPEBRQTOS, 02.46, 01.28, TAR...
# 454      [3, 2), NUNEBROTOS, 03.51, 04:41, TARHRES, 2824]
# 455        [=3, [2624, NUNEBRQTOS, 10.40, 11.33, TARURES]
# 456       [=3, {25241, NUNSBRPTOS, 00:34, 01.28, TARURES]
# 457     [=3, ª, NUNEBROTOS, 03.29, 01.28, TARHRES, 25245]
# 458      [23, 1, 2424, NUNEBROTOS, 10.40, 11.26, TARURES]
# 459       [3, =, {2624, NUNEBRRTOS, 1251, 11.33, TARHRES]
# 460          [0, 2124, NUNEBRQTOS, 13.35, 12.42, TARURES]
# 461          [2, NUNEBRQTOS, 10.38, 09.41, TARHRES, 2624]
# 462      [=3, 1, NUNSBRPTOS, 08.57, 09.27, TARHRES, 2924]
# 463          [0, 2124, NUNEBRBTOS, 10.38, 09.46, TARHRES]
# 464     [=3, ª, NUNEBRQTOS, 05:51, 05.26, TARHRES, 9, ...
# 465        [23, [2924, NUNEBRRTOS, 06.35, 05.27, TARHRES]
# 466          [5, 2524, NUNEBRRTOS, 07:01, 06.02, TARHRES]
# 467         [3, [2624, NUNEBROTOS, 03.51, 02.52, TARHRES]
# 468                                  [3, Uatis , 1, 2924]
# 469     [=3, ª, NUNEBRPTOS, 09.16, 09.27, TARHRES, 9, ...
# 470       [=3, [29241, NUNEBRQTOS, 03.51, 01.58, TARHRES]
# 471     [=3, 9, @, 2524, NUNEBRBTOS, 12.23, 11.33, TAR...
# 472     [3, 0 ), 2124, NUNEBRQTOS, 03.51, 04-18, TARHRES]
# 473        [=3, 52924, NUNEBRQTOS, 03:51, 01.28, TARURES]
# 474          [523, 2424, NUNEBRQTOS, 00:000o.43, TARHRES]
# 475     [23, Tuy, NUNEBRQTOS, 10.38, 09.29, TARHRES, "...
# 476     [=3, 7, ª, NUNEBRRTOS, 02.33, 01.28, TARHRES, ...
# 477      [23, [2624, NUNEBRBTOS, 1421, 13.07, TARHRES, 9]
# 478     [3, 2), RUI TAVARES, Livre, NUNEBRBTOS, 0O:000...
# 479     [=3, PEDRO NUNO SANTOS, PS, ª, NUNEBROTOS, 00:...
# 480     [=3, 24, EslATVAS, #, 2624, NUNEBROTOS, 02.27,...
# 481     [23, ª, {2524, NUNEBRBTOS, 05.16, 05.26, TARHRES]
# 482          [0), 224, NUNEBROTOS, 03.51, 01.28, TARURES]
# 483       [31, 82624, NUNPEBROTOS, 13.52, 13.04, TARHRES]
# 484              [224, NUNEBRQTOS, 10.38, 09.29, TARURES]
# 485     [3, 1, I, {2(24, NUNEBRQTOS, 07,41, 07.13, TAR...
# 486        [2 ), 2424, NUNEBRQTOS, 06.45, 05.32, TARHRES]
# 487        [523, NUNEBRQTOS, 13.35, 12.34, TARURES, 2624]
# 488       [3, 9, 2124, NUNEBRBTOS, 08.22, 07.41, TARURES]
# 489     [8, ª, NUNEBRBTOS, 08.22, 08:56, TARURES, 9, 2...
# 490     [23, 2), 2024, NUNEBRQTOS, 03.51, 04*39, TARURES]
# 491     [24, 7, Ltivas, 2124, NUNPEBROTOS, 08.22, 08.3...
# 492      [23, 8, NUNEBRQTOS, 13.35, 11.33, TARHRES, 2924]
# 493          [9, 2124, NUNEBRQTOS, 08.22, 07.50, TARHRES]
# 494      [23, ª, NUNSBROTOS, 04-26, 05.26, TARURES, 2924]
# 495      [=3, ª, 2424, NUNEBROTOS, 07-16, 07.13, TARHRES]
# 496          [3, 820=, NUNEBRQTOS, 06.22, 05.27, TARURES]
# 497          [, 2124, NUNPSBRQTOS, 10.38, 10.04, TARHRES]
# 498         [23, {224, NUNEBRBTOS, 10.08, 09.29, TARURES]
# 499             [NUNGBROTOS, 07:59, 07.13, TARHRES, 2624]
# 500     [=3, 3, ª, NUNEBRPTOS, 03.22, 01.28, TARHRES, ...
# 501      [23, ª, NUNEBRQTOS, 10.40, 11:18, TARHRES, 2924]
# 502      [3, 0), 2924, NUNEBRQTOS, 03.51, 01:44, TARURES]
# 503          [0), 224, NUNEBRBTOS, 03.51, 01.29, TARHRES]
# 504         [d, 72424, NUNEBRQTOS, 07.12, 06.17, TARHRES]
# 505       [523, [2524, NUNEBRQTOS, OO:OO, 01:07, TARHRES]
# 506        [23, 82624, NUNEBROTOS, 03.51, 04:08, TARHRES]
# 507        [9), {2124, NUNEBRRTOS, 08.22, 09.23, TARHRES]
# 508        [23, [2624, NUNEBRQTOS, 07.54, 07.13, TARHRES]
# 509         [0), 2(24, NUNEBRQTOS, 03.51, 01.45, TARHRES]
# 510       [=3, 826241, NUNEBROTOS, 08.22, 09.04, TARURES]
# 511       [23, 9, NUNEBRQTOS, 00:0000:35, TARURES, "2424]
# 512      [=3, 1, NUNEBRQTOS, 13.34, 11.33, TARHRES, 2924]
# 513     [=23, 1, NUNEBRQTOS, 01:14, 01.28, TARHRES, 2624]
# 514          [3, 2124, NUNSBR TOS, 03.51, 04.50, TARHRES]
# 515       [3, 1, NUNEBRQTOS, 03.55, 05.15, TARHRES, 2124]
# 516          [23, 82624, NUNEBRQTOS, 00:0000.24, TARHRES]
# 517         [=3, 82424, NUNSBR TOS, OO:OOlOo:oo, TARHRES]
# 518     [23, 82(24, NUNEBRQTOS, 09.50, 09.29, TARURES, 9]
# 519            [2424, NUNPEBRNTOS, 10.38, 09.31, TARHRES]
# 520        [=3, {2624, NUNEBROTOS, 08.32, 09.27, TARHRES]
# 521        [=3, 82524, NUNEBROTOS, 10.14, 09.29, TARHRES]
# 522     [=3, ª, NUNEBROTOS, 04:12, 05.26, TARHRES, 9, ...
# 523      [=3, 1, NUNEBRQTOS, 10.18, 09.29, TARHRES, 2924]
# 524     [=3, ª, NUNEBRQTOS, 07-16, 07.13, TARURES, 9, ...
# 525          [3, 2124, NUNEBRRTOS, 06.26, 05.27, TARHRES]
# 526         [2), 2624, NUNEBRQTOS, 07.12, 06.35, TARHRES]
# 527       [=3, 1, NUNEBRQTOS, 0051, 01.28, TARHRES, 2924]
# 528     [=3, ª, NUNPEBRBTOS, 08.22, 09.27, TARHRES, 9,...
# 529         [2(24, NUNEBRPTOS, 03.51, 03.11, TARHRES, 1)]
# 530        [=3, 82524, NUNEBRPTOS, 10.45, 11.33, TARHRES]
# 531       [3, 2(24, NUNEBRPTOS, 03.51, 03.23, TARHRES, 5]
# 532          [9, 2(24, NUNEBRQTOS, 03.04, 01.28, TARURES]
# 533                                                  [=3]
# 534         [23, 8242, NUNEBRQTOS, 04853, 05.26, TARHRES]
# 535     [=3, 82124, NUNEBRQTOS, 08.16, 07.13, TARURES, 9]
# 536      [3, 9), 2124, NUNEBRBTOS, 03.51, 02.57, TARHRES]
# 537     [2(24, 71 |, FslatAS, [, 8210, NUNEBRQTOS, 00:...
# 538       [23, [25241, NUNEBRBTOS, 13.35, 11.33, TARHRES]
# 539     [=3, 1, [, 2624, NUNEBRPTOS, 14:23, 13.09, TAR...
# 540       [=23, 82624, NUNEBRQTOS, OO:OO, 01:15, TARURES]
# 541     [=3, ª, [2624, NUNSBRPTOS, 12.15, 11.33, TARURES]
# 542     [=3, 7, ª, NUNEBROTOS, 10.27, 09.29, TARHRES, ...
# 543          [2124, NUNEBRNTOS, 13.35, 12.43, TARURES, 7]
# 544         [23, NUNEBROTOS, 08.22, 08.47, TARHRES, 2924]
# 545     [=23, 1, NUNEBRQTOS, OO:OO, 01:19, TARURES, 2924]
# 546         [3, [2924, NUNEBRRTOS, 06.59, 05.52, TARHRES]
# 547        [23, [2524, NUNEBROTOS, 04:47, 05.26, TARURES]
# 548     [=3, {2624, NUNEBRQTOS, 13.32, 11.33, TARHRES, 9]
# 549          [=3, 2624, NUNEBRQTOS, 00:0010O:25, TARURES]
# 550        [24/, 2024, NUNEBRBTOS, 03.51, 01.40, TARURES]
# 551     [=3, 9, #, 2424, NUNEBROTOS, 07-16, 07.13, TAR...
# 552     [=3, 1, =, ª, NUNSBROTOS, 02.49, 01.28, TARHRE...
# 553      [=3, 1, NUNEBRRTOS, 03.51, 02.40, TARHRES, 2924]
# 554      [8, 2424, NUNEBRQTOS, 07.12, 06.48, TARHRES, 7d]
# 555      [3, 9), NUNSBRBTOS, 08.22, 08.20, TARHRES, 2624]
# 556        [=3, {2624, NUNEBROTOS, 12.22, 11.33, TARHRES]
# 557      [3, 0), 2424, NUNSBRQTOS, 10.38, 10.30, TARURES]
# 558       [23, 9, 2524, NUNEBROTOS, 10.38, 1114, TARURES]
# 559         [=3, 82624, NUNEBRRTOS, 10.38, 11O6, TARURES]
# 560      [=3, ª, 2424, NUNEBRRTOS, 10.24, 09.29, TARHRES]
# 561          [=3, 8252, NUNEBRQTOS, 1137, 11.33, TARURES]
# 562     [Rn, ª, NUNEBROTOS, 1O:01, 09.29, TARURES, 9, ...
# 563     [=3, {2624, NUNEBROTOS, 02.00, 01.28, TARHRES, 9]
# 564          [3, 8212, NUNEBRQTOS, 09.35, 09.27, TARURES]
# 565      [23, ª, 2624, NUNEBRRTOS, 06.53, 05.47, TARURES]
# 566          [2124, NUNEBRQTOS, 13.35, 12.38, TARURES, 6]
# 567     [=3, {2524, NUNEBRQTOS, 09.20, 09.27, TARHRES, 9]
# 568      [23, , 2{241, NUNEBRQTOS, 10.38, 10.54, TARHRES]
# 569     [=3, ª, NUNEBRBTOS, 08.37, 09.27, TARHRES, 9, ...
# 570      [=3, 1, NUNSBRPTOS, 08.35, 09.27, TARHRES, 2524]
# 571           [3, 8242, NUNEBRQTOS, 1411, 13.04, TARHRES]
# 572            [82624, NUNEBRQTOS, 08.22, 07.13, TARHRES]
# 573        [=3, 32424, NUNEBRQTOS, OO:OO, 01.28, TARHRES]
# 574        [23, {2524, NUNEBRBTOS, 09.18, 09.27, TARHRES]
# 575        [23, [2624, NUNEBRQTOS, 08.22, 07.13, TARHRES]
# 576         [9), 2124, NUNEBRRTOS, 08.22, 07.44, TARHRES]
# 577         [23, 2(24, NUNEBRQTOS, 07.13, 06.55, TARYRES]
# 578       [=23, [2924, NUNEBRQTOS, OO:OO, 01:02, TARHRES]
# 579                        [FSLATIVANC, [, 8202, 1624, n]
# 580     [=3, i, ª, NUNEBROTOS, 03.34, 01.28, TARHRES, ...
# 581       [=3, 826245, NUNEBRQTOS, 03.51, 01.28, TARHRES]
# 582     [=3, , ª, NUNEBRRTOS, 01:29, 01.28, TARHRES, 9...
# 583       [=23, 82424, NUNEBRQTOS, OO:OO, 01:08, TARURES]
# 584          [2124, NUNEBROTOS, 08.22, 09.25, TARYRES, 5]
# 585            [2124, NUNPEBRQTOS, 13.35, 11:59, TARURES]
# 586      [=3, ª, 2624, NUNEBRQTOS, 05.14, 05.26, TARHRES]
# 587     [=3, WIG>, 2, PEDRO, OO:OO, 01.28, RUI, NUNO S...
# 588     [=3, ª, NUNEBRQTOS, 02.17, 01.28, TARHRES, 9, ...
# 589         [{2624, NUNEBRBTOS, 08.22, 07.13, TARURES, 9]
# 590        [2 ), 2924, NUNSBRQTOS, 03.53, 04*56, TARHRES]
# 591      [3, 2), 2124, NUNEBRQTOS, 03.51, 04-23, TARHRES]
# 592       [723, [2924, NUNEBRQTOS, 03.51, 02.15, TARHRES]
# 593     [3, ª, NUNEBRPTOS, 03.51, 03.05, TARURES, 9, 2...
# 594     [=3, ª, NUNEBRQTOS, 00:30, 01.28, TARHRES, 9, ...
# 595           [3, 2424, NUNEBRBTOS, 00:00l0O:16, TARURES]
# 596     [=3, 9, ª, NUNEBRQTOS, 02:55, 01.28, TARURES, ...
# 597     [23, 1, PEDRO, 08.22, 08.41, RUI, NUNO SANTOS,...
# 598        [=3, 82424, NUNEBRBTOS, 08.22, 09.27, TARHRES]
# 599     [3, 2), RUI TAVARES, Livre, 2024, NUNEBRQTOS, ...
# 600       [23, 4, NUNEBRQTOS, 03.51, 02.54, TARURES, 2l4]
# 601       [23, [25241, NUNEBRQTOS, 11:49, 11.33, TARURES]
# 602     [=3, PEDRO NUNO SANTOS, PS, ª, NUNEBRQTOS, 00:...
# 603      [=3, ª, NUNEBRBTOS, 03:55, 05.26, TARHRES, 2924]
# 604     [=3, {2624, NUNEBR TOS, OO:OI, 01.28, TARHRES, 9]
# 605     [=3, [2624, NUNEBRPTOS, 07-45, 07.13, TARURES, 9]
# 606      [=3, 1, NUNEBROTOS, 08.52, 09.27, TARHRES, 2924]
# 607     [3, 5, 9, 2624, NUNEBRQTOS, 14836, 13.13, TARH...
# 608         [=3, 2624, NUNEBRRTOS, OO:OO, 01*23, TARHRES]
# 609          [2, 2124, NUNEBR8TOS, 06.45, 05.36, TARHRES]
# 610     [23, 5, NUNEBRQTOS, 08.22, 08.40, TARURES, 94241]
# 611                             [HAIR, RUI CANENTO SALON]
# 612          [1, NUNEBROTOS, 14:14, 13.04, TARURES, 2924]
# 613       [=3, 82624, NUNEBRQTOS, 11:12, 11:.33, TARHRES]
# 614        [73, 82(24, NUNEBRBTOS, 05.59, 05.26, TARURES]
# 615     [23, 2 ), 2924, NUNEBRQTOS, 03.51, 04837, TARH...
# 616         [0), 2124, NUNPEBRQTOS, 13.35, 1151, TARHRES]
# 617     [33, 12s, {2624, NUNEBRPTOS, 05.26, 05.26, TAR...
# 618        [=3, {2624, NUNEBRRTOS, 09.03, 09.27, TARHRES]
# 619     [=3, ª, NUNSBROTOS, 13.35, 13.02, TARURES, 9, ...
# 620     [=3, {2624, NUNEBRPTOS, 10.31, 09.29, TARHRES, 9]
# 621          [9, 2124, NUNEBRBTOS, 08.22, 08:17, TARURES]
# 622        [31, 24241, NUNEBRRTOS, 03.51, 04830, TARHRES]
# 623     [=3, {2624, NUNEBROTOS, 05.15, 05.26, TARHRES, 9]
# 624      [=3, ª, 2624, NUNEBRPTOS, 12.55, 11.33, TARHRES]
# 625     [=3, ª, NUNEBROTOS, 12.41, 11.33, TARHRES, 9, ...
# 626        [53, 82624, NUNEBRQTOS, 03.51, 04:01, TARURES]
# 627       [3, 2124, NUNEBRQTOS, 08.22, 07.55, TARURES, 5]
# 628          [2), 21241, NUNEBRQTOS, 00:00OO:31, TARHRES]
# 629      [=3, , 82524, NUNEBROTOS, 01.38, 01.28, TARHRES]
# 630          [3, 2124, NUNEBRQTOS, 10.38, 10.18, TARHRES]
# 631          [3, 2124, NUNEBRQTOS, 03.52, 04:51, TARURES]
# 632      [=3, ª, 2624, NUNEBRBTOS, 07-47, 07.13, TARHRES]
# 633     [=3, [2624, NUNEBROTOS, 06.04, 05.26, TARHRES, 9]
# 634      [=3, ª, NUNEBRBTOS, 01:57, 01.28, TARHRES, 2924]
# 635     [3, 0) , 2124, NUNEBRPTOS, 03.51, 03.07, TARURES]
# 636       [3, ª, 2124, NUNEBRPTOS, 09.25, 09.27, TARHRES]
# 637     [=3, 9, #, NUNEBROTOS, 07-45, 07.13, TARURES, ...
# 638                                         [73, 1, 2024]
# 639     [23, ª, NUNEBRBTOS, 1424, 13.10, TARHRES, 9, 2...
# 640     [3, 2//, 2624, NUNEBRBTOS, 08.22, 07-29, TARHRES]
# 641     [=3, {2624, NUNEBRRTOS, 12.26, 11.33, TARHRES, 9]
# 642           [3, 2024, NUNEBRQTOS, 00:0010O:14, TARURES]
# 643      [7, 24241, NUNEBR TOS, 07.12, 06.51, TARURES, 9]
# 644      [=3, 9, NUNEBRQTOS, 03.53, 04:59, TARHRES, 2124]
# 645        [=3, [2924, NUNEBRQTOS, OO:OO, 01:18, TARURES]
# 646         [2), 2424, NUNEBROTOS, 07.12, 06.19, TARHRES]
# 647      [=3, 1, NUNEBRBTOS, 10:11, 09.29, TARHRES, 2924]
# 648       [3, 2124, NUNEBROTOS, 10.38, 10.38, TARURES, 5]
# 649      [3, 2624, NUNEBRBTOS, 08.22, 07.31, TARHRES, Da]
# 650      [23, 0, NUNEBRQTOS, 03.51, 01:50, TARHRES, 2624]
# 651        [=3, 52624, NUNEBRQTOS, 08.22, 09.08, TARHRES]
# 652         [2), 2624, NUNEBRBTOS, 07.12, 06.30, TARHRES]
# 653     [23, É, NUNEBRBTOS, 03.53, 04:58, TARHRES, 96241]
# 654     [3, 2, 2124, NUNEBRQTOS, 03.51, 04-27, TARURES...
# 655            [1, 224, NUNEBRBTOS, 13.35, 1253, TARHRES]
# 656     [=3, 9, ª, 2624, NUNGBRPTOS, 02.22, 01.28, TAR...
# 657          [2124, NUNGBROTOS, 10.38, 09.39, TARHRES, 5]
# 658      [3, 0), 2624, NUNEBROTOS, 08.22, 08.39, TARHRES]
# 659        [23, [2624, NUNEBROTOS, 06.12, 05.26, TARHRES]
# 660                                        [[GeCskehnqee]
# 661        [23, [2624, NUNSBR TOS, 08.22, 09.08, TARHRES]
# 662     [FslanAS , 4, 9, NUNEBRQTOS, 10.40, 11.33, TAR...
# 663      [53, 826241, NUNEBRBTOS, 07.03, 06:.04, TARURES]
# 664     [=3, 1, PEDRO, RUI, #, NUNO SANTOS, 06.50, 05....
# 665              [224, NUNSBROTOS, 08.22, 07.13, TARURES]
# 666      [23, 1, NUNSBROTOS, 09.44, 09.28, TARHRES, 2624]
# 667       [3, 2424, NUNEBRRTOS, 08.22, 07.37, TARHRES, 5]
# 668           [3, 824, NUNEBRQTOS, 14836, 13.14, TARHRES]
# 669             [2424, NUNEBR TOS, 05.49, 05.26, TARHRES]
# 670      [=3, , 82524, NUNEBRQTOS, 00:26, 01.28, TARHRES]
# 671      [31, 5, 2624, NUNEBRQTOS, 11-27, 11.33, TARHRES]
# 672     [523, ª, NUNEBRQTOS, 07.16, 07:11, TARHRES, 2124]
# 673     [=3, 2(, PEDRO, 06.45, 05.27, RUI, NUNO SANTOS...
# 674     [=3, 9, ª, {2524, NUNEBROTOS, 03.18, 01*28, TA...
# 675     [=3, =, 1, PEDRO, RUI, #, NUNO SANTOS, 02.53, ...
# 676     [3, 9, ª, NUNEBROTOS, 02.46, 01.28, TARURES, 2...
# 677      [3, 3, {2624, NUNEBR TOS, 07.04, 06.05, TARXRES]
# 678         [3, [2924, NUNEBRQTOS, 03.51, 02.47, TARHRES]
# 679     [3, 2 /, 2124, NUNEBROTOS, 08.22, 08.14, TARHRES]
# 680     [=3, 1, PEDRO, 09.40, 09.27, RUI, NUNO SANTOS,...
# 681         [3, 82424, NUNEBROTOS, 03.51, 03.45, TARHRES]
# 682        [23, [2524, NUNEBROTOS, 08.22, 08.45, TARHRES]
# 683     [523, ª, NUNEBRQTOS, 01-08, 01.28, TARHRES, 9,...
# 684        [=3, 82624, NUNEBROTOS, 10.40, 11.33, TARHRES]
# 685       [3, 8262, NUNEBRQTOS, 07.13, 07.07, TARHRES, 9]
# 686      [=3, 1, NUNEBRQTOS, 03.51, 02.30, TARHRES, 2924]
# 687     [23, ª, [2624, NUNPEBRQTOS, 05.11, 05.26, TARH...
# 688      [=3, ª, NUNEBRRTOS, 10:19, 09.29, TARHRES, 2624]
# 689        [0), 2124, NUNPEBRBTOS, 13.35, 12.00, TARURES]
# 690       [1, 8, NUNEBROTOS, 01:55, 01.28, TARHRES, 2924]
# 691     [33, 1, [2424, NUNGBROTOS, 14:03, 13.04, TARHRES]
# 692      [23, ª, 2424, NUNEBRBTOS, 07.51, 07.13, TARHRES]
# 693           [, 2624, NUNEBRQTOS, 07.12, 06.53, TARHRES]
# 694     [38, 2/, 2424, NUNEBRBTOS, 10.38, 10.44, TARYRES]
# 695            [2424, NUNPGBRRTOS, 06:09, 05.26, TARURES]
# 696        [523, 2624, NUNEBRQTOS, 10:56, 11.33, TARURES]
# 697      [=3, ª, 2424, NUNEBRRTOS, 12.02, 11.33, TARHRES]
# 698                              [laprairie, SWITZERLAND]
# 699      [3, 0), 2624, NUNEBRQTOS, 08.22, 07.24, TARURES]
# 700         [=3, 8262, NUNPEBRQTOS, OO:OOlOO:oo, TARURES]
# 701      [3, 0), NUNEBRQTOS, 10.38, 10.32, TARHRES, 2424]
# 702                [ALDO, Shop online, ALD O SH OES . PT]
# 703                                          [=23, [2524]
# 704     [33, 9, ª, NUNEBRQTOS, 02.43, 01.28, TARHRES, ...
# 705         [=23, 82624, NUNEBRQTOS, 00:000o:37, TARURES]
# 706      [3, 25, 2624, NUNEBRQTOS, 03.51, 04:45, TARHRES]
# 707           [826241, NUNEBRRTOS, 07.05, 06.06, TARHRES]
# 708     [=3, ª, NUNEBRBTOS, 03.38, 01.28, TARHRES, 9, ...
# 709      [31, 2, 2(24, NUNEBRQTOS, 03.51, 03.29, TARHRES]
# 710          [2124, NUNEBROTOS, 13.35, 12.39, TARURES, 9]
# 711      [=3, #, 2424, NUNEBRQTOS, 14:04, 13.04, TARHRES]
# 712      [=3, 1, NUNEBRBTOS, 05.47, 05.26, TARURES, 2924]
# 713      [=3, ª, NUNEBRRTOS, 02.15, 01.28, TARHRES, 2524]
# 714     [ESLATI, {, 2624, NUNEBRRTOS, 07-16, 07.13, TA...
# 715        [23, 82(24, NUNEBROTOS, 14.18, 13.06, TARHRES]
# 716       [0), NUNPEBRBTOS, 13.35, 12.13, TARURES, 28241]
# 717      [=3, ª, NUNEBRBTOS, 13.26, 11.33, TARURES, 2924]
# 718          [0 ), 224, NUNEBRQTOS, 03.51, 0135, TARHRES]
# 719       [3, 9, 2424, NUNEBRBTOS, 08.22, 08.33, TARHRES]
# 720          [], 2424, NUNEBRQTOS, 06.45, 05.41, TARURES]
# 721     [=3, 9, 1, NUNEBROTOS, 03.12, 01.28, TARHRES, ...
# 722     [=3, 4, ª, NUNEBRQTOS, 01.24, 01.28, TARURES, ...
# 723     [3, 7lihb, 6, 2(24, NUNEBRBTOS, 00:000O:26, TA...
# 724     [=3, 1, =, ª, {2524, NUNEBRBTOS, 03.15, 01.28,...
# 725      [=3, 1, NUNEBRRTOS, 08.22, 09.03, TARHRES, 2924]
# 726      [=3, ª, 2624, NUNEBROTOS, 08.11, 07.13, TARHRES]
# 727     [3, 9), NUNPEBRBTOS, 10.38, 10.33, TARHRES, 2424]
# 728      [=3, 1, NUNEBROTOS, 09.31, 09.27, TARHRES, 2924]
# 729        [723, 82624, NUNEBROTOS, 03.51, 0403, TARHRES]
# 730     [=3, 1, 1, NUNEBRBTOS, 03.33, 01.28, TARHRES, ...
# 731          [8227, NUNEBRQTOS, 12.32, 11.33, TARURES, 9]
# 732        [23, 82624, NUNEBRBTOS, 07.12, 06.27, TARHRES]
# 733          [2124, NUNEBROTOS, 13.35, 12.03, TARHRES, 8]
# 734        [23, 82524, NUNEBRQTOS, 10.38, 11:04, TARURES]
# 735     [723, ª, NUNEBRQTOS, 01:16, 01.28, TARHRES, 2624]
# 736          [9, 2124, NUNEBRBTOS, 08.22, 09.22, TARHRES]
# 737        [21, 82(24, NUNEBRRTOS, 05.33, 05.26, TARHRES]
# 738      [23, 1, NUNEBRRTOS, 10.46, 11.33, TARHRES, 2924]
# 739     [=3, hr, ª, NUNEBROTOS, 13.08, 11.33, TARHRES,...
# 740     [=3, 0, PEDRO, RUI, NUNO SANTOS, 10.40, 11.33,...
# 741          [3, 2124, NUNPEBRNTOS, 0O:00100:18, TARHRES]
# 742     [523, 1, NUNEBRQTOS, 11.44, 11.33, TARURES, 2624]
# 743          [s, 2124, NUNEBRQTOS, 10.38, 09.43, TARHRES]
# 744       [3, 1, NUNEBRPTOS, 06.34, 05.27, TARURES, 2924]
# 745     [23, [2624, NUNEBROTOS, 09.06, 09.27, TARHRES, 9]
# 746            [[2624, NUNEBRQTOS, 11:14, 11.33, TARURES]
# 747      [73, 1, 2124, NUNEBRQTOS, 03.15, 01.28, TARHRES]
# 748         [2, NUNEBRBTOS, 13.35, 12.12, TARHRES, 28241]
# 749     [3, 1, ª, NUNEBROTOS, 03.19, 01.28, TARHRES, 2...
# 750      [=3, 1, NUNEBROTOS, 08.22, 09.27, TARHRES, 2624]
# 751     [=3, ª, NUNEBRBTOS, 03.04, 01.28, TARHRES, 2, ...
# 752     [=3, ª, NUNEBROTOS, 04-22, 05.26, TARHRES, 9, ...
# 753     [23, 9, 6, 32(241, NUNEBR TOS, 07.12, 06.13, T...
# 754          [1, NUNEBRRTOS, 11:08, 11.33, TARHRES, 2924]
# 755     [=3, ª, [2624, NUNEBRQTOS, 12.20, 11.33, TARHRES]
# 756         [0, 52124, NUNEBRQTOS, 10.38, 10.07, TARHRES]
# 757      [=3, ª, NUNSBROTOS, 07.35, 07.13, TARURES, 2924]
# 758         [2 /, 224, NUNEBROTOS, 03.51, 01.28, TARHRES]
# 759     [23, =, ª, NUNEBRBTOS, 12.31, 11.33, TARHRES, ...
# 760     [=3, ª, NUNEBRQTOS, 08.44, 09.27, TARHRES, 9, ...
# 761     [23, ª, NUNEBRQTOS, 05.52, 05.26, TARHRES, 9, ...
# 762                                         [3, 9), 2624]
# 763        [=3, 82624, NUNEBRQTOS, 09.07, 09.27, TARHRES]
# 764     [3, 2124, NUNEBRBTOS, 10.38, 10.15, TARURES, 0...
# 765           [3, 224, NUNEBRQTOS, 13.35, 12.34, TARHRES]
# 766           [3, 267, NUNEBRQTOS, 13.35, 12.50, TARHRES]
# 767     [=3, 82624, NUNEBRPTOS, 10.50, 11.33, TARHRES, 9]
# 768      [3, 2124, NUNEBROTOS, 08.22, 08.34, TARURES, 5]]
# 769      [3, 9), 2124, NUNEBRQTOS, 03.51, 03.32, TARHRES]
# 770     [=3, 7, 2|, 1, NUNEBROTOS, 02.59, 01.28, TARHR...
# 771      [=3, ª, NUNEBROTOS, 12.06, 11.33, TARHRES, 2524]
# 772      [=73, 826241, NUNEBRRTOS, 08.22, 09.07, TARURES]
# 773     [31, 0), 2(24, NUNPEBROTOS, 03.51, 03.17, TARU...
# 774                      [31, DEBATE, 2(24, LEGISLATIVAS]
# 775     [3, 22, PEDRO, 03.44, 01.28, RUI, NUNO SANTOS,...
# 776          [1, NUNEBRQTOS, 10.03, 09.29, TARHRES, 2924]
# 777        [23, 82241, NUNSBRRTOS, 08.22, 08.48, TARHRES]
# 778         [2), 2124, NUNEBROTOS, 03.51, 03.03, TARURES]
# 779       [3, NUNEBROTOS, 08.22, 08.15, TARURES, 0, 2624]
# 780              [224, NUNEBRBTOS, 13.35, 12.58, TARHRES]
# 781      [=3, ª, 2424, NUNEBRQTOS, 03.36, 01.28, TARURES]
# 782     [73, ª, NUNEBROTOS, 03.07, 01.28, TARURES, 9, ...
# 783      [31, 0), 224, NUNEBROTOS, 03.51, 01.47, TARHRES]
# 784     [523, ª, NUNPEBROTOS, 08.22, 09:.01, TARURES, ...
# 785         [3, 32624, NUNEBRQTOS, 13.35, 12.34, TARURES]
# 786        [=3, 82124, NUNEBRRTOS, 08.32, 09.27, TARHRES]
# 787          [9, 2124, NUNEBRQTOS, 08.22, 08.54, TARURES]
# 788     [23, 5, ª, 2624, NUNSBRPTOS, 12.08, 11.33, TAR...
# 789     [23, 9, [, NUNEBRQTOS, 10.40, 1120, TARURES, 2...
# 790         [0), 2424, NUNEBRQTOS, 03.51, 02.54, TARHRES]
# 791     [=3, 1, z, 1, NUNEBRQTOS, 02.56, 01.28, TARHRE...
# 792        [33, {2624, NUNEBRBTOS, 05.21, 05.26, TARHRES]
# 793          [0), 2124, NUNEBRBTOS, 13.35, 1147, TARURES]
# 794     [=3, ª, NUNEBRBTOS, 08.25, 09.27, TARHRES, 9, ...
# 795        [23, 72424, NUNEBRBTOS, OO:OO, 00.34, TARURES]
# 796     [3, 9), RUI TAVARES, Livre, 2124, NUNEBRBTOS, ...
# 797       [=3, 827, NUNEBRQTOS, 00:46, 01.28, TARURES, 5]
# 798        [=3, 822, NUNEBRQTOS, 01II, 01.28, TARURES, 9]
# 799        [3, 2), 2424, NUNEBROTOS, 00:000o.33, TARHRES]
# 800     [=3, 24, ESLATIVAS, 2624], NUNEBRPTOS, 10.44, ...
# 801      [53, 8262, NUNEBRQTOS, 01:05, 01.28, TARHRES, 9]
# 802      [=3, ª, NUNSBROTOS, 06.02, 05.26, TARHRES, 2924]
# 803                       [3, DEBATE, 2424, LEGISLATIVAS]
# 804        [73, 82624, NUNEBRQTOS, 03.55, 05.24, TARURES]
# 805          [3, 8262, NUNEBRQTOS, 07.13, 07.02, TARHRES]
# 806     [=3, , Y], ª, NUNEBRQTOS, 02.05, 01.28, TARHRE...
# 807      [3, 9), 2424, NUNGBRRTOS, 10.38, 10.50, TARHRES]
# 808          [2, 2624, NUNSBR TOS, 07.12, 06.39, TARURES]
# 809       [3, 2, 2624, NUNEBRBTOS, 06.45, 05.34, TARHRES]
# 810        [=3, [2924, NUNEBRPTOS, 09.29, 09.27, TARHRES]
# 811      [3, {2624, NUNEBRPTOS, 07-40, 07.13, TARHRES, 9]
# 812        [23, NUNEBRQTOS, OO:OO, 01.28, TARURES, "2424]
# 813     [=3, , =, ª, NUNEBROTOS, 03.01, 01.28, TARHRES...
# 814      [=3, ª, 2(24, NUNEBRQTOS, 09.52, 09.29, TARURES]
# 815                          [ESLATIVAS, G, [2424, 0624 ]
# 816          [0), 2124, NUNEBROTOS, 13.35, 1201, TARURES]
# 817      [=3, 1, NUNEBRPTOS, 07-16, 07.13, TARHRES, 2924]
# 818          [9, 2124, NUNEBROTOS, 13.35, 11.56, TARHRES]
# 819             [2(24, NUNEBRQTOS, 03.51, 03.16, TARHRES]
# 820       [31, 24, 2124, NUNEBRQTOS, 00:000O.27, TARURES]
# 821       [=3, ª, NUNEBRBTOS, 01.28, 0128, TARHRES, 2924]
# 822          [1, 2(24, NUNGBR TOS, 03.04, 01.28, TARHRES]
# 823      [3, 0), 2124, NUNGBRQTOS, 10.38, 10.34, TARURES]
# 824      [1, 2124, NUNEBRQTOS, 12.32, 11.33, TARYRES, An]
# 825     [=3, 1, PEDRO, RUI, 9, NUNO SANTOS, 01:58, 01....
# 826          [3, 2124, NUNEBRQTOS, 10.38, 10.21, TARHRES]
# ...
# 1769    [=3, 2, 72424, NUNEBRPTOS, 11:05, 11.33, TARHRES]
# 1770         [2124, NUNEBRBTOS, 13.35, 11.35, TARHRES, )]
# 1771     [31, 2, 2124, NUNEBRBTOS, 03.51, 04838, TARHRES]
# 1772    [=3, ª, NUNEBROTOS, 00.22, 01.28, TARURES, 9, ...
# 1773     [=3, 1, NUNSBRRTOS, 08:50, 09.27, TAPHRES, 2924]
# 1774     [=3, ª, NUNEBRQTOS, 04:49, 05.26, TARHRES, 2924]
# 1775      [3, 2, 2124, NUNEBRQTOS, 03.51, 04:08, TARHRES]
# 1776       [23, {2624, NUNEBROTOS, 12.42, 11.33, TARURES]
# 1777         [0, 2124, NUNEBRQTOS, 13.35, 12.32, TARURES]
# 1778        [9), NUNGBRRTOS, 10.38, 10.39, TARURES, 2624]
# 1779    [=3, ª, NUNEBRRTOS, 02.14, 01.28, TARHRES, 9, ...
# 1780        [23, NUNEBRQTOS, 13.35, 12.34, TARURES, 2624]
# 1781    [=3, PEDRO NUNO SANTOS, PS, 82624, NUNEBRRTOS,...
# 1782     [73, ª, 2424, NUNEBRRTOS, 03.09, 01.28, TARHRES]
# 1783      [=28, {2624, NUNEBRPTOS, 09.49, 09.29, TARHRES]
# 1784    [23, 9, @, NUNPEBRQTOS, 01.22, 01.28, TARHRES,...
# 1785     [33, ª, NUNEBRBTOS, 01.33, 01.28, TARHRES, 2924]
# 1786        [0), 2124, NUNEBRQTOS, 13.35, 12.23, TARURES]
# 1787       [723, [212, NUNEBRQTOS, 00:43, 01.28, TARHRES]
# 1788       [23, 82124, NUNEBRQTOS, 08.22, 09.27, TARHRES]
# 1789     [=3, ª, NUNEBRQTOS, 07-59, 07.13, TARHRES, 2924]
# 1790                                            [9, 2624]
# 1791     [=3, 1, 2624, NUNEBROTOS, 13:17, 11.33, TARHRES]
# 1792     [3, 9), 2124, NUNEBRRTOS, 08.22, 08.36, TARHRES]
# 1793       [3, [29241, NUNSBR TOS, 06.59, 06:00, TARURES]
# 1794       [=23, 82624, NUNEBRQTOS, 1126, 11.33, TARURES]
# 1795         [3, 8262, NUNEBRRTOS, 03.55, 05.12, TARURES]
# 1796    [23, Ai, NUNEBRQTOS, 10.40, 11.33, TARHRES, 29...
# 1797       [0), NUNPEBRNTOS, 13.35, 12.24, TARURES, 2424]
# 1798        [23, 82524, NUNEBR TOS, 10.38, 1112, TARHRES]
# 1799    [1, RUI TAVARES, Livre, 2024, NUNEBRQTOS, 06.4...
# 1800            [2124, NUNEBROTOS, 08.22, 08.10, TARURES]
# 1801        [0), 2124, NUNEBRQTOS, 13.35, 12.25, TARHRES]
# 1802      [=3, [2924, NUNPEBRQTOS, 10.38, 11.13, TARHRES]
# 1803        [0), 2124, NUNEBROTOS, 03.51, 01:31, TARURES]
# 1804     [3, 0), NUNEBRRTOS, 03.51, 03.34, TARHRES, 2824]
# 1805    [23, 82624, NUNEBRQTOS, 03.51, 01.28, TARHRES, 9]
# 1806     [=3, ª, NUNEBROTOS, 10.21, 09.29, TARHRES, 2624]
# 1807    [=3, 6/80, NUNEBRQTOS, 03.51, 04:08, TARURES, ...
# 1808         [6, 2(24, NUNEBRBTOS, 03.04, 01.28, TARURES]
# 1809    [=3, 7, ª, NUNEBRQTOS, 02.46, 01.28, TARHRES, ...
# 1810             [224, NUNEBROTOS, 03.51, 01.32, TARHRES]
# 1811                            [224, Utwas, 9, FE, 2524]
# 1812     [81, 1, 2624, NUNEBRBTOS, 07.12, 06.40, TARURES]
# 1813        [=3, 2124, NUNEBRQTOS, 13.35, 12.34, TARHRES]
# 1814        [=3, 224, NUNPEBROTOS, 13.35, 12.34, TARURES]
# 1815     [=3, 1, NUNEBROTOS, 13.35, 11.33, TARHRES, 2924]
# 1816    [23, ª, [2624, NUNSBROTOS, 11:59, 11.33, TARHRES]
# 1817       [=3, 82424, NUNEBRQTOS, O1:1O, 01.28, TARURES]
# 1818           [{2424, NUNSBRRTOS, 05.55, 05.26, TARHRES]
# 1819    [=3, ª, NUNEBRQTOS, 01.26, 01.28, TARHRES, 9, ...
# 1820     [1, 82124, NUNGBRRTOS, 10.38, 10.03, TARHRES, 9]
# 1821    [723, 1, 8, {2(241, NUNEBRQTOS, I1:OO, 11.33, ...
# 1822    [1, PEDRO, 11-08, 11.33, RUI, 9, NUNO SANTOS, ...
# 1823      [3, 9, 2424, NUNEBRQTOS, 08.22, 08.21, TARHRES]
# 1824        [3, [2424, NUNEBRQTOS, 14:08, 13.04, TARHRES]
# 1825                                                  [3]
# 1826       [3, 826245, NUNEBRRTOS, 03.51, 02.03, TARHRES]
# 1827     [73, ª, 2424, NUNSBROTOS, 02.38, 01.28, TARHRES]
# 1828              [CENTENÁRIO, CRAFTINC SHOES SINCE 1941]
# 1829       [=3, {2624, NUNEBRQTOS, 12.43, 11.33, TARHRES]
# 1830     [=3, 1, NUNEBROTOS, 01:15, 01.28, TARHRES, 2624]
# 1831    [3, 2), RUI TAVARES, Livre, 2124, NUNEBROTOS, ...
# 1832         [1, NUNEBRPTOS, 04-04, 05.26, TARURES, 2624]
# 1833         [0/, 224, NUNEBROTOS, 13.35, 12.36, TARURES]
# 1834    [73, {2624, NUNSBR TOS, 12.53, 11.33, TARHRES, 9]
# 1835         [7, 2124, NUNEBRQTOS, 10.35, 09.29, TARHRES]
# 1836         [NUNSBROTOS, 08.22, 09.24, TARHRES, 2, 2424]
# 1837    [523, 1, NUNEBRRTOS, OO:OO, 01:20, TARHRES, 2924]
# 1838     [=3, ª, NUNEBRPTOS, 04:18, 05.26, TARHRES, 2924]
# 1839        [23, 8242, NUNEBRQTOS, 07.15, 07:09, TARHRES]
# 1840       [=3, 82424, NUNEBROTOS, 13.56, 13.04, TARHRES]
# 1841    [=3, ª, NUNEBROTOS, 10.41, 11.33, TARURES, 9, ...
# 1842         [3, 2(24, NUNEBRQTOS, 07.51, 07.13, TARURES]
# 1843    [=3, ª, NUNEBRBTOS, 03.08, 01.28, TARHRES, 9, ...
# 1844       [23, [2924, NUNEBRQTOS, 10.38, 10.51, TARHRES]
# 1845         [0), 224, NUNEBRBTOS, 03.51, 01.28, TARURES]
# 1846          [[25241 , NUNEBRPTOS, 03.51, 0151, TARYRES]
# 1847    [=3, ª, NUNSBRRTOS, 05.28, 05.26, TARHRES, 9, ...
# 1848     [3, 0), 2024, NUNEBRQTOS, 03.51, 03.15, TARURES]
# 1849    [=3, [2624, NUNEBRQTOS, 03.51, 03.41, TARHRES, 9]
# 1850       [0), NUNEBRQTOS, 13.35, 12:19, TARHRES, 28241]
# 1851    [=3, 1, NUNPEBROTOS, 11:55, 11.33, TARHRES, 2924]
# 1852       [23, 82624, NUNEBRQTOS, 03.51, 03.55, TARHRES]
# 1853       [23, [2924, NUNEBRQTOS, 03.51, 02.17, TARYRES]
# 1854                                        [=3, ª, 2924]
# 1855        [0), 2124, NUNEBRQTOS, 03.51, 01.36, TARHRES]
# 1856    [=3, ª, NUNEBRQTOS, 01:5O, 01.28, TARHRES, 9, ...
# 1857         [2124, NUNEBRQTOS, 13.35, 12.34, TARHRES, C]
# 1858         [0), 224, NUNEBROTOS, 03.51, 03.18, TARURES]
# 1859         [9, 2424, NUNEBRQTOS, 08.22, 07.14, TARHRES]
# 1860    [=3, ª, 2(24, NUNPEBRBTOS, 07.16, 07.13, TARURES]
# 1861       [=3, 824245, NUNEBRRTOS, 00:00l0O:38, TARURES]
# 1862         [ª, 2124, NUNEBRQTOS, 05.55, 05.26, TARHRES]
# 1863            [2124, NUNEBRQTOS, 08.22, 08.32, TARHRES]
# 1864     [1, NUNEBRQTOS, 12.42, 11.33, TARURES, T5, 2424]
# 1865     [3, ª, NUNPEBRBTOS, 00:37, 01*28, TARURES, 2524]
# 1866    [=3, ª, NUNEBRQTOS, 0724, 07.13, TARHRES, 9, 2...
# 1867         [3, 2424, NUNEBRQTOS, 08.22, 07.23, TARHRES]
# 1868    [=23, [2624, NUNEBRPTOS, 07.13, 06.59, TARURES...
# 1869    [=3, ª, NUNEBROTOS, 07.57, 07.13, TARHRES, 9, ...
# 1870    [31, 0), 2024, NUNEBROTOS, 03.51, 03.35, TARHRES]
# 1871    [124, ISLATIVAS, 9, 05, 2124, NUNEBRQTOS, 08.2...
# 1872      [3, 1, NUNEBRQTOS, 03.51, 02.46, TARHRES, 2924]
# 1873    [528, 1, NUNEBRPTOS, 11.42, 11.33, TARURES, 2624]
# 1874         [7, 2124, NUNEBRQTOS, 10.38, 09.59, TARURES]
# 1875     [=3, 1, NUNEBROTOS, 09.04, 09.27, TARHRES, 2924]
# 1876    [=3, ª, NUNEBRRTOS, 05.27, 05.26, TARHRES, 9, ...
# 1877        [0), 2(24, NUNEBROTOS, 03.51, 01:46, TARHRES]
# 1878    [23, 1, NUNEBRRTOS, OO:OO, 01.28, TARHRES, 9, ...
# 1879         [53, 822, NUNEBRQTOS, O1:OI, 01.28, TARHRES]
# 1880        [=23, 822, NUNEBRQTOS, 04*58, 05.26, TARHRES]
# 1881       [23, 82624, NUNSBRPTOS, 03.51, 03.53, TARURES]
# 1882         [2), 2124, NUNEBRBTOS, 00:00l0O:30, TARHRES]
# 1883    [=3, {2624, NUNEBRPTOS, 08.38, 09.27, TARHRES, 9]
# 1884     [=3, 1, NUNSBRRTOS, 08.27, 09.27, TARHRES, 2924]
# 1885    [luni, 8224, NUNEBRRTOS, 00.20, 01.28, TARHRES...
# 1886     [=3, 1, NUNEBRBTOS, 10.40, 11.33, TARHRES, 2924]
# 1887    [=3, =, ª, NUNEBRBTOS, 03.03, 01.28, TARHRES, ...
# 1888     [=3, 1, NUNSBR TOS, 03.51, 02.36, TARHRES, 2924]
# 1889    [=3, ª, NUNEBRBTOS, 01.43, 01.28, TARHRES, 9, ...
# 1890         [1, 2124, NUNGBROTOS, 09.43, 09.27, TARHRES]
# 1891        [=3, {2624, NUNEBROTOS, 0035, 01.28, TARHRES]
# 1892        [0), NUNEBRQTOS, 13.35, 12.08, TARHRES, 2824]
# 1893    [23, ª, NUNEBROTOS, 01.46, 01.28, TARHRES, 9, ...
# 1894     [23, 1, 72424, NUNPEBROTOS, 10.40, 117, TARYRES]
# 1895         [3, 2124, NUNEBRBTOS, 10.38, 10.16, TARHRES]
# 1896     [=3, [2624, NUNEBRQTOS, 10.40, 1128, TARHRES, 9]
# 1897                                           [3, [2924]
# 1898    [=3, 9, #, 2624, NUNEBRBTOS, 11:50, 11.33, TAR...
# 1899       [23, [2924, NUNEBRQTOS, 08.22, 08.44, TARHRES]
# 1900    [31, 0), 2924, NUNPEBRQTOS, 03.51, 01.48, TARU...
# 1901        [1, 26241, NUNEBRBTOS, 08.22, 08.51, TARHRES]
# 1902    [3, 1, [25241 , NUNEBRRTOS, 03.51, 02.05, TARH...
# 1903    [23, 1, PEDRO, RUI, 9, NUNO SANTOS, 12.13, 11....
# 1904     [=3, 1, NUNEBRQTOS, 03.53, 04*52, TARHRES, 2924]
# 1905         [2124, NUNEBRQTOS, 08.22, 07.57, TARHRES, 5]
# 1906         [3, 8262, NUNEBRQTOS, 06.33, 05.27, TARURES]
# 1907         [2124, NUNEBRQTOS, 08.22, 07-16, TARHRES, 2]
# 1908    [31, 9), 2424, NUNEBRQTOS, 03.51, 03.31, TARHRES]
# 1909    [=3, ª, NUNEBRQTOS, 10:17, 09.29, TARXRES, 9, ...
# 1910       [23, {2524, NUNEBRQTOS, 08.51, 09.27, TARHRES]
# 1911        [9), NUNGBRQTOS, 08.22, 09.19, TARURES, 2124]
# 1912      [23, 826241, NUNEBRQTOS, 05.10, 05.26, TARHRES]
# 1913    [=3, ], ª, 2424, NUNSBRBTOS, 02.48, 01.28, TAR...
# 1914     [3, 2), 2624, NUNEBRQTOS, 07.12, 06.36, TARHRES]
# 1915    [31, RUI TAVARES, Livre, 72424, NUNPEBRQTOS, 0...
# 1916      [=3, {25241, NUNEBRRTOS, 10.40, 11.33, TARHRES]
# 1917    [3, 9 ), 2424, NUNEBROTOS, 07.12, 06.23, TARHRES]
# 1918    [23, ª, NUNEBROTOS, 09.30, 09.27, TARHRES, 9, ...
# 1919    [=3, ª, NUNSBROTOS, 05.48, 05.26, TARHRES, 9, ...
# 1920       [3, [29241, NUNEBR TOS, 03.51, 02.08, TARHRES]
# 1921     [=3, ª, 2424, NUNEBRQTOS, 10.30, 09.29, TARHRES]
# 1922           [{2624, NUNEBROTOS, 11:39, 11.33, TARHRES]
# 1923     [23, 1, NUNEBRQTOS, 11:15, 11.33, TARHRES, 2924]
# 1924       [=3, {2524, NUNEBRQTOS, 08.50, 09.27, TARHRES]
# 1925          [, 2124, NUNEBRQTOS, 10.38, 09.44, TARURES]
# 1926       [=3, {2424, NUNEBRQTOS, 06.23, 05.27, TARURES]
# 1927                                           [2), 2124]
# 1928    [=3, ª, NUNEBROTOS, 07.37, 07.13, TARURES, 9, ...
# 1929    [23, {2624, NUNEBRBTOS, 07.58, 07.13, TARHRES, 9]
# 1930    [523, Me, 1, 22, NUNEBRQTOS, 07-16, 07.13, TAR...
# 1931        [0), 224, NUNPEBRQTOS, 13.35, 12.14, TARURES]
# 1932    [=3, 9, #, NUNEBRRTOS, 12.42, 11.33, TARURES, ...
# 1933      [3, 9, 2124, NUNEBRQTOS, 08.22, 07-59, TARHRES]
# 1934    [0), RUI TAVARES, Livre, NUNEBROTOS, 13.35, 11...
# 1935          [3, NUNEBROTOS, 09.42, 09.27, TARHRES, 924]
# 1936      [23, 826241, NUNEBROTOS, 03.55, 05.26, TARURES]
# 1937         [0, 2124, NUNEBROTOS, 03.51, 03.08, TARHRES]
# 1938      [3, 2, 2624, NUNSBROTOS, 03.51, 04-13, TARHRES]
# 1939    [723, ª, NUNEBRQTOS, 03.55, 05.22, TARHRES, 2924]
# 1940     [=3, 1, NUNEBROTOS, 00:17, 01.28, TARHRES, 2924]
# 1941         [9, NUNEBROTOS, 08.22, 09.15, TARURES, 2124]
# 1942     [31, 2, 2124, NUNEBRQTOS, 10.38, 10.28, TARHRES]
# 1943        [=3, [2524, NUNEBRQTOS, OO:OO, 01ll, TARURES]
# 1944    [0), RUI TAVARES, Livre, NUNPEBRBTOS, 13.35, 1...
# 1945     [3, 2), 2624, NUNEBRBTOS, 08.22, 08.38, TARYRES]
# 1946    [23, 4, {2624, NUNEBRBTOS, 10.09, 09.29, TARHR...
# 1947    [=3, ª, 2424, NUNPEBRQTOS, 08:O1, 07.13, TARHRES]
# 1948    [33, PEDRO NUNO SANTOS, PS, ª, 2624, NUNEBRBTO...
# 1949           [{2624, NUNEBRBTOS, 03.04, 01.28, TARURES]
# 1950     [=3, ª, NUNEBROTOS, 02.19, 01.28, TARURES, 2524]
# 1951         [2424, NUNEBRQTOS, 08.22, 07.13, TARURES, 5]
# 1952    [=23, 1, NUNEBRQTOS, 03.51, 02.26, TARHRES, 2924]
# 1953      [=33, [2524, NUNEBRQTOS, OO:OO, 00.47, TARHRES]
# 1954        [=3, 8224, NUNEBRQTOS, 09.45, 09.29, TARHRES]
# 1955         [3, 22 ", NUNEBR TOS, 06.20, 05.27, TARHRES]
# 1956     [=3, 1, NUNEBRRTOS, 13.12, 11.33, TARHRES, 2924]
# 1957    [31, 7, {2124, NUNEBRBTOS, 10.38, 09.55, TARHRES]
# 1958         [3, 2624, NUNEBRQTOS, 07.55, 07.13, TARURES]
# 1959    [723, 1, NUNEBRRTOS, 03.51, 03.52, TARURES, 2624]
# 1960       [21241, NUNEBROTOS, 03.51, 01.28, TARHRES, 98]
# 1961     [=3, ª, 2424, NUNEBRBTOS, 07-46, 07.13, TARHRES]
# 1962                                      [ROSA&TEIXEIRA]
# 1963     [=3, 1, NUNEBRRTOS, 08.24, 09.27, TARHRES, 2924]
# 1964         [82(2, NUNEBRBTOS, 02.46, 01.28, TARHRES, 3]
# 1965       [523, 82624, NUNEBRQTOS, 0O:00l0O:49, TARURES]
# 1966         [3, 8212, NUNEBRRTOS, 04837, 05.26, TARURES]
# 1967     [=3, ª, NUNEBRBTOS, 10.28, 09.29, TARHRES, 2924]
# 1968                                                 [52]
# 1969      [723, 82624, NUNEBROTOS, 03.51, 03.50, TARURES]
# 1970    [=3, 2, 5, 2424, NUNEBRPTOS, 10.38, 10.56, TAR...
# 1971    [3, 9, [, [2424, NUNEBROTOS, 03.51, 01:56, TAR...
# 1972           [NUNEBRBTOS, 13.35, 12.59, TARHRES, 24245]
# 1973      [3, ª, NUNSBRPTOS, 07.23, 07.13, TARHRES, 2924]
# 1974       [0), NUNPEBROTOS, 13.35, 12.44, TARYRES, 2024]
# 1975           [[2124, NUNEBRQTOS, 06.17, 05.27, TARHRES]
# 1976    [31, 24, , 2424, NUNEBROTOS, OO:OO, 01.27, TAR...
# 1977    [=3, 7, 5, {2624, NUNEBROTOS, 02.54, 01.28, TA...
# 1978           [[2624, NUNEBR TOS, 03.51, 02.06, TARYRES]
# 1979    [73, ª, NUNEBRQTOS, 03.35, 01.28, TARHRES, 2, ...
# 1980        [=3, [2924, NUNEBRBTOS, 0O:00lOO:41, TARHRES]
# 1981     [=3, 1, NUNEBRQTOS, 13.10, 11.33, TARHRES, 2924]
# 1982       [=3, {2624, NUNEBRQTOS, 12.59, 11.33, TARHRES]
# 1983     [3, 0), 2624, NUNEBROTOS, 08.22, 07.25, TARHRES]
# 1984       [=3, 82524, NUNEBROTOS, 01.48, 01.28, TARURES]
# 1985    [=3, ª, NUNEBRBTOS, 05.57, 05.26, TARHRES, 9, ...
# 1986         [0, NUNEBROTOS, 13.35, 12.34, TARHRES, 2824]
# 1987      [3, 1, NUNEBRQTOS, 08.22, 08.52, TARHRES, 2924]
# 1988        [0), NUNEBRPTOS, 08.22, 08.22, TARHRES, 2524]
# 1989            [NUNEBRQTOS, 10.38, 09.29, TARURES, 2124]
# 1990      [3, 0, 2024, NUNEBRQTOS, 10.38, 10.23, TARHRES]
# 1991            [2(24, NUNEBRQTOS, 03.51, 03.12, TARYRES]
# 1992     [=3, ª, NUNSBROTOS, 05.56, 05.26, TARHRES, 2924]
# 1993    [=3, 9, , NUNPEBRBTOS, 10.40, 11.33, TARURES, ...
# 1994     [=3, 1, NUNSBROTOS, 08.15, 07.13, TARURES, 2924]
# 1995    [=3, ª, NUNEBRBTOS, 09.14, 09.27, TARHRES, 9, ...
# 1996    [=3, [2624, NUNEBRBTOS, 12.32, 11.33, TARHRES, 9]
# 1997     [73, ª, NUNEBROTOS, 03.32, 01.28, TARHRES, 2524]
# 1998        [23, 824241, NUNEBRPTOS, 00:000O:39, TARURES]
# 1999       [=3, 82624, NUNSBRBTOS, 00:32, 01.28, TARHRES]
# 2000     [523, [25241, NUNEBRPTOS, 09.56, 09.29, TARHRES]
# 2001         [2424, NUNEBRQTOS, 10.38, 09.30, TARURES, 1]
# 2002     [23, 1, NUNEBRQTOS, 03.53, 05.06, TARURES, 2924]
# 2003    [=3, 82C, NUNEBRQTOS, 05.04, 05.26, TARURES, 041]
# 2004    [=3, 82124, NUNEBRQTOS, 07-41, 07.13, TARHRES, 9]
# 2005         [0), 224, NUNEBRQTOS, 13.35, 12.20, TARHRES]
# 2006       [=3, [2924, NUNEBRQTOS, 11:03, 11.33, TARHRES]
# 2007                      [31, DEBATE, 224, LEGISLATIVAS]
# 2008                                            [3, 2624]
# 2009    [=3, ª, NUNEBROTOS, 10.38, 09.29, TARHRES, 9, ...
# 2010       [=3, [2624, NUNEBRQTOS, 05.08, 05.26, TARHRES]
# 2011       [=3, [2924, NUNEBRBTOS, 11:09, 11.33, TARURES]
# 2012      [523, 1, NUNEBRQTOS, OO:OOOO:50, TARURES, 2924]
# 2013         [2424, NUNEBROTOS, 10.38, 10.22, TARURES, 5]
# 2014       [23, {2124, NUNEBRQTOS, 13.39, 13.02, TARHRES]
# 2015        [7, 2124, NUNPEBROTOS, 13.35, 12.47, TARHRES]
# 2016    [=3, {2624, NUNEBRQTOS, 08.06, 07.13, TARHRES, 9]
# 2017     [=3, 9, 2(24, NUNEBRQTOS, OO:OO, 01.23, TARHRES]
# 2018       [=3, 82524, NUNEBRBTOS, 06.58, 05.49, TARURES]
# 2019     [23, 8, NUNEBRPTOS, 07.52, 07.13, TARHRES, 2924]
# 2020    [=3, 91, ª, NUNEBRQTOS, 02.29, 01.28, TARHRES,...
# 2021     [=3, 1, NUNEBRQTOS, 14-29, 13.10, TARHRES, 2924]
# 2022      [523, [2524, NUNEBRQTOS, 03.51, 03.57, TARHRES]
# 2023           [[2524, NUNEBRQTOS, 13.46, 13.04, TARHRES]
# 2024    [23, =, NUNEBRQTOS, OO:OO, 01.28, TARURES, 72424]
# 2025            [2424, NUNEBRPTOS, 05.41, 05.26, TARHRES]
# 2026    [=3, , ª, NUNEBRBTOS, 04:15, 05.26, TARHRES, 9...
# 2027       [23, 82624, NUNEBROTOS, 03.51, 04-04, TARHRES]
# 2028      [3, 1, NUNEBRQTOS, 14.13, 13.04, TARHRES, 2924]
# 2029                                          [523, 2124]
# 2030       [=3, [2524, NUNEBRQTOS, 03.51, 02.19, TARHRES]
# 2031          [[24241, NUNEBRRTOS, 11:O6, 11.33, TARHRES]
# 2032    [28, ª, NUNEBRPTOS, 09.39, 09.27, TARHRES, 9, ...
# 2033    [31, 1, 26241, NUNEBRRTOS, 13.53, 13.04, TARHRES]
# 2034    [523, 1, NUNEBRBTOS, 11.35, 11.33, TARHRES, 2624]
# 2035     [=3, 1, NUNEBROTOS, 06.47, 05.43, TARHRES, 2924]
# 2036     [73, , [2624, NUNEBROTOS, 02.36, 01.28, TARHRES]
# 2037     [1, 92024, NUNEBROTOS, 12.32, 11.33, TARHRES, G]
# 2038     [=3, 1, NUNEBRQTOS, 11838, 11.33, TARURES, 2924]
# 2039                                                  [3]
# 2040    [=3, PEDRO NUNO SANTOS, PS, 1, NUNEBRQTOS, 0O:...
# 2041    [=3, 9, #, 2624, NUNEBROTOS, 08.06, 07.13, TAR...
# 2042        [3, [2524, NUNSBR TOS, 07.13, 06.57, TARHRES]
# 2043     [23, ª, 2424, NUNEBRBTOS, 05.12, 05.26, TARHRES]
# Name: text, dtype: object

# %%
#Analyse and clean text

def time_str_to_float(time_str):
    # Split the string on the period to separate minutes and seconds
    minutes_str, seconds_str = time_str.split('.')
    # Convert strings to integer and float, respectively
    minutes = int(minutes_str)
    seconds = float(seconds_str)
    # Convert seconds to a fraction of a minute
    seconds_fraction = seconds / 60.0
    # Return as float
    return minutes + seconds_fraction

#first lets order the images

data = data.sort_values(by='filename')


pd.set_option('display.max_rows', None)

pattern_n = r'\bNUN\w+\b'

pattern_T = r'\bTA\w+\b'

count = 0

Used_list = []


# Iterate over the rows of the DataFrame starting from index 73
for i in range(122, len(data)):

    # Extract the list from the specified column
    data_inside = data.iloc[i, 4]

    # Iterate over each string in the list
    for j in range(len(data_inside)):

        # Check if the pattern matches the string
        if re.search(pattern_n, data_inside[j]):
            

            # If pattern is found, extract the current string and the next three strings
            desired_info = data_inside[j:j+4]  # Extract the next three strings

            translated_info = []
            for item in desired_info:
                if re.match(pattern_n, item):
                    translated_info.append("Pedro Nuno Santos")
                elif re.match(pattern_T, item):
                    translated_info.append("Rui Tavares")
                else:
                    translated_info.append(item)

            # Append the translated_info to Used_list
            Used_list.append(translated_info)


# Filter out lists with exactly 4 objects
Used_list = [desired_info for desired_info in Used_list if len(desired_info) == 4]

Used_list = [sublist for sublist in Used_list if "PEDRO NUNO SANTOS" not in sublist]


# Initialize arrays to store Montenegro and Ventura times
PNS_times = []
Rui_times = []


for list in Used_list:
 
    # Get the first two characters
    first_part_m = list[1][:2]

    # Get the last two characters
    second_part_m = list[1][-2:]

    first_part_v = list[2][:2]

    second_part_v = list[2][-2:]
    
     # Join the Montenegro parts with a period in the middle
    PNS_time = f"{first_part_m}.{second_part_m}"

    # Join the Ventura parts with a period in the middle
    Rui_time = f"{first_part_v}.{second_part_v}"
    
    # Append the times to the arrays
    PNS_times.append(PNS_time)
    Rui_times.append(Rui_time)


PNS_times = [time.replace('O', '0').replace('I', '1').replace('l', '1') for time in PNS_times]
Rui_times = [time.replace('O', '0').replace('I', '1').replace('l', '1') for time in Rui_times]



# Filter out any strings that contain 'Ru'
PNS_times_filtered = [time for time in PNS_times if 'Ru' not in time]
Rui_times_filtered = [time for time in Rui_times if 'Ru' not in time]

# Filter out any strings that contain '1q'
Rui_times_filtered1 = [time for time in Rui_times_filtered if '1q' not in time]


# Now the conversion again
PNS_minutes = [time_str_to_float(time) for time in PNS_times_filtered]
Rui_minutes = [time_str_to_float(time) for time in Rui_times_filtered1]

total_debate_time = 40


total_speech_turns = max(len(PNS_minutes), len(Rui_minutes))

# Calculate the average duration per speech turn in minutes
average_duration_per_turn = total_debate_time / total_speech_turns

# Generate x-axis values corresponding to the actual time in minutes
x_axis_time = [i * average_duration_per_turn for i in range(total_speech_turns)]

# Use the same x-axis for both speakers, assuming both arrays cover the entire debate duration
plt.figure(figsize=(8, 6))
plt.plot(x_axis_time[:len(PNS_minutes)], PNS_minutes, label='Pedro Nuno Santos', linewidth=2.5)
plt.plot(x_axis_time[:len(Rui_minutes)], Rui_minutes, label='Rui Tavares', linewidth=2.5)

# Optionally add shaded area between the lines
plt.fill_between(x_axis_time[:min(len(PNS_minutes), len(Rui_minutes))], 
                 PNS_minutes[:min(len(PNS_minutes), len(Rui_minutes))], 
                 Rui_minutes[:min(len(PNS_minutes), len(Rui_minutes))], color='grey', alpha=0.3)

# Setting up the plot with labels and title
plt.xlabel('Time (minutes)')
plt.ylabel('Speaking Time (minutes)')
plt.title('Speaking Time Evolution Across Debate Duration')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(loc='upper left', fontsize='large', frameon=True, shadow=True)

# Adjust the x-axis and y-axis limits to fit the data
plt.xlim(0, total_debate_time)
plt.ylim(0, max(max(PNS_minutes), max(Rui_minutes)) + 1)

plt.tight_layout()
plt.show()

# %% [markdown]
# BE - PS

# %%
# Load the pickle file into a DataFrame
data = pd.read_pickle('be-ps.pkl')

print(data.iloc[:, 4])
# Out:
# 0       [3, 0), 9, 22, MORRAAA, 00:0010O:58, NUNEBRQTOs ]
# 1        [9, @, 2524, MORRIAGA, 11.27, 10.51, NUNEBRBTOS]
# 2               [221, MORRAGA, 03.14, 03.47, NUNPEBRQTOS]
# 3            [=3, 82624, MRRAGA, 01:36, 0121, NUNEBRQTOS]
# 4       [3, 1 ), 2, @, MORRAGA, 00:0000.23, NUNPEBRPTo...
# 5       [424, SLATIVAS, 9, MRRAGA, 00:000O:30, NUNEBRO...
# 6                [MORRAGA, 11.27, 13.04 NuNfEBRBTos, 7al]
# 7           [73, 224, MORRAGA, 09.28, 10.07, NUNEBROTOs ]
# 8            [2, 224, MORRAGA, 12.22, 13.59, NUNPEBRPTOS]
# 9                [22, MORRIAAA, 13.31, 14:00, NUNEBROTOS]
# 10           [3, 8262, MORRAAA, 14-27, 15.06, NUNEBRQTOS]
# 11        [3, 2124, MORRAAUA, 05.43, 04:14, NUNPEBRPTos ]
# 12      [=3, 9, 5, 12024, MORRAGA, 05.43, 05.22, NUNEB...
# 13       [=3, MPARIAGA, 07.58, 06.59, NUNPEBRPTos , 2424]
# 14            [=3, 27, MARAGHA, 09.47, 1011, NUNEBROTOs ]
# 15              [22, MPRRAAA, 11.27, 13.33, NUNPEBRPTos ]
# 16               [224, MPRRIAGA, 1127, 10.51, NUNEBRQTOS]
# 17          [73, MORRAAA, 09.19, 10.07, NUNPEBRPTos , 24]
# 18                [MORRIAGA, 03.14, 04:04 NuNfBRBTos, 42]
# 19            [Pen, 824, MPARAGA, 06.38, 06.O2 NuNBR?Tos]
# 20        [23, 1, MORRAAA, 01.28, 0121, NUNEBRQTOS, 2924]
# 21             [MRRAGA, 11.27, 12.05, NUNEBRPTos |, 9024]
# 22           [3, 224, MPARIAGA, 02.23, 03.06, NUNEBRPTOs]
# 23      [3, 7, 2, [, MRRAGA, 01:45, 02.29, NUNEBROTOs,...
# 24           [7=3, 224, MORRAGA, 09.38, 10.08 NuNBR Tos ]
# 25            [22, MOARIAGHA, 11:19, 10.51, [NUNPEBRQTOS]
# 26            [23, 82424, MORRAGA, OO:OOOO:OONunfgR8Tos ]
# 27          [723, MORRAGA, 01:07, 0121, NUNPEBRPTos , 27]
# 28              [224, MORRAAA, 1127, 13.42, [NUNEBRRTos ]
# 29           [3, 224, MRRAGA, 07.58, 06.21, NUNPEBRPTos ]
# 30         [=3, {2124, MORRAAA, 07.55, 06.02, NUNEBRQTOS]
# 31      [3, 5s, [, 224, MORRAGA, 01:45, 02.18, NUNEBRQ...
# 107     [=3, ClNAs, 1, 2124, MRRAGA, OO:OOOO:OONungRPT...
# 108      [3, 1, 22, MPRRIAGA, 01:45, 01.45, NUNPEBRPTos ]
# 109       [23, 1, MRRAAA, 02.12, 03.06, NUNEBRQTOS, 2924]
# 110         [=3, [2424, MRRAGA, 05.21, 04:06, NUNEBRQTOS]
# 111     [82624, MPRRIAGGA, 11.27, 13.59, NUNEBRQTos |, 9]
# 112              [224, MORRAGA, 14833, 15.06, NUNEBRQTOs]
# 113           [224, MPRRIAGA, 03.14, 04:05, NUNPEBRPTos ]
# 114            [MOARIAGHA, 14803, 1405, NUNEBRPTOs, 2124]
# 115        [=3, 1, MRRAGA, 01.45, 0121, NUNEBRQTOS, 2924]
# 116                       [3, DEBATE, 2424, LEGISLATIVAS]
# 117           [MOARIAGHA, 1211, 13.59, NUNEBRQTos |, 221]
# 118            [MRRAGA, 11.27, 13.57, NUNPEBRPTos , 2121]
# 119     [3, 7, 7224, MORRAGA, 05.43, 05.27, NUNPEBRPTo...
# 120      [3, 0), 22, MMRRAAA, 07.58, 09.54, NUNPEBRPTos ]
# 121             [224, MORRAGDA, 1127, 13.45, NUNEBROTOs ]
# 122        [73, MPRRIAGA, 03.49, 04:05, NUNEBRQTOs, 2424]
# 123                                             [CLARINS]
# 124       [=3, 82524, MPRRIAGA, 07-21, 06.02, NUNEBRQTOS]
# 125     [24, Sas, 82424, MORRAGA, 03.14, 03.35, NUNEBR...
# 126     [=3, 1, MORRAGDA, 02.28, 03.06, NUNEBRQTOS, 2924]
# 127        [3, 2, 22, MORRAAA, 11-27, 1103, NUNEBRPTos |]
# 128        [3, [2424, MORRAGGA, 14*28, 15.06, NUNEBRQTOS]
# 129     [23, {2624, ESLAIWAS, 82624, MRRAAA, OO:OO, 01...
# 130          [3, MORRAGUA, 07.58, 07.24, NUNEBRBTOs, 274]
# 131     [=23, MPRRIAGA, 04-20, 04:06, NUNEBRQTos |, 2424]
# 132        [MORRAGA, 07-58, 07.58, [NUNPEBRBTOS ., 21241]
# 133       [PA, 2424, MPARAGA, 10.35, 10.51, [NUNPEBRQToS]
# 134     [73, 2(24, 44, 1, FsLATIVAS, [, 2524, MPRRIAGA...
# 135     [3, 2, 4, {2624, MARIANA, 05.43, 05.01, PEDRO,...
# 136          [8, MORRAGA, 06.23, 06.02, NUNEBRQTOS, 2424]
# 137      [=3, 1, MORRAGA, 01:35, 0121, NUNEBRQTOS, 29241]
# 138     [31, 4, 9, MORRAAA, 11-27, 12.14, NUNPEBRPTos ...
# 139        [23, 82624, MORRAAA, 01:45, 02.04, NUNEBRQTOS]
# 140        [8, 224, MOARAGHA, 07-58, 08.35, NUNEBRQTOs |]
# 141        [23, 82624, MORRAAA, 01.45, 03.06, NUNEBRQTOS]
# 142     [3, 2, 9, 9224, MRRAGA, 01.45, 02.48, NUNEBROT...
# 143           [3, 8262, MORRAAA, 11:04, 1051, NUNEBRQTOS]
# 144       [723, MRRAGUA, 01.22, 01:21, NUNPEBRPTOS, 0524]
# 183         [8, MORRAGA, 07.58, 08.05 NuNBR Tos |, 94241]
# 184      [=3, 82524, MRRAAA, 10.59, 10.51, NUNEBRQTOS, 9]
# 185     [=3, 82524, MOARAQA, 10.33, 10.23, NUNEBRQTOS, 9]
# 186            [23, MORRAAA, 04833, 04:06 NuNfBRBTos, 22]
# 187         [3, 82524, MORRAAA, 0O:.59, 0121, NUNEBRQTOS]
# 188     [3, 9), 9, 22, MORRAGA, OO:OO, O1:02, NUNPEBRP...
# 189     [3, 224, MORRAAA, 01:45, 01.37, [NUNPEBRPTos ,...
# 190        [3, ', MORRAAA, 11.27, 1051, NUNEBRQTOs, 9824]
# 191     [523, 2(24, FSLATIVA, 1, G, 2524, MPARAGUA, OO...
# 192     [723, 5, MORRIAQA, 14:03, 1457, NUNPEBRPTos , 22]
# 193          [3, 224, MRRAGA, 01:45, 01*37, NUNPEBRPTos ]
# 194             [224, MORRAGA, 15.08, 15.06, NUNEBROTos ]
# 195         [3, 224, MORRAGA, 03.57, 04:05, NUNPEBRPTos ]
# 196         [3, 82124, MORRAGA, 05.00, 04:06, NUNEBRQTOS]
# 197                     [DIREÇÃO DE INFORMAÇÃO, RTP 2024]
# 198      [=3, 8262, MORRAAA, 07.52, 06.02, NUNEBRQTOS, 9]
# 199       [=3, 1, MORRAGA, 01.32, 0121, NUNEBRQTOS, 2524]
# 200        [3, [2424, MORRAAA, 05.12, 04:06, NUNPEBRPTOS]
# 201           [MOARAGHA, 12.50, 13.59, [NUNEBR Tos , 224]
# 202         [3, [2524, MRRAGGA, 04:59, 04:06, NUNEBRQTOS]
# 203                         [3, 2124, 1qATIVAS', 1, 2124]
# 204              [22, MARAGA, 12.09, 13.59, [NUNEBR Tos ]
# 205      [==3, 2(24, MORRAGA, 07:00, 06.02, NUNPEBRPTos ]
# 206     [=3, 7, 9, MARIANA, 07.58, 08.44, PEDRO, MORTÁ...
# 207     [23, VAs, 9, MRRAGA, 01.45, 01.37, NUNPEBRPTos...
# 208          [224, MPRRIAGA, 13.48, 14805, [NUNPEBRPTos ]
# 209         [=3, 8212, MORRAAA, 11238, 13.59, NUNEBRQTOS]
# 210     [3, 2), 9, 2024, MORRAGA, 01:45, 02.38, NUNPEB...
# 211     [=3, ª, MORRAAA, 03.15, 04:05, NUNEBRQTOS, 9, ...
# 212           [2024, MORRAAA, 07.36, 06.02, NUNPEBRPTos ]
# 213     [3, 5, @, MRRAGA, 01:45, 03.04, NUNPEBRPTos |,...
# 214     [773, 2424, MPARIAGA, 07.58, 06.42, NUNEBROTOs |]
# 215         [23, 2124, MORRAGA, 06.21, 06.02, NUNEBRQTOS]
# 216       [=3, {2524, MZARAAGA, 05.55, 06:0O, NUNEBRQTOS]
# 217       [73, 5, MRRAGA, 01.45, 01.34, NUNEBRQTos , 224]
# 218     [=3, 9, MOARIAGHA, 04:45, 04:06, NUNPEBRPTos ,...
# 219     [23, [2924, MORRIAGHA, 07-58, 10.02, NUNPEBRQT...
# 220     [73, AS, ª, 2124, MORRAGA, 01:45, 01:29, NUNPE...
# 221        [73, 224, MORRAGA, 09.55, 10:11, [NUNEBRPTos ]
# 222             [MOAFIAAA, 13.35, 14.04, NUNPEBRPTos , {]
# 223                                             [0, 2124]
# 224           [3, MRRAGA, 14.20, 15.06, NUNEBROTos |, 24]
# 225        [723, 2124, MOARIAGHA, 08.26, 1O.02 NuNBR Tos]
# 226           [3, 2424, MRRAGA, 05.19, 04:06, NUNEBROTOs]
# 227       [23, ], MRRAGA, 07.58, 09.20, NUNEBRQTOs, 2424]
# 228       [=3, 1, MRRAGA, 07-06, 06.02, NUNEBRQTOS, 2924]
# 229        [3, 224, MORRAAA, 11.27, 11:39, [NUNPEBRQTos ]
# 230      [3, 9, 72, MORRAAA, OO:OO, 01:08, NUNPEBRPTos |]
# 231               [MORRAGA, 12.12, 13.59, NUNEBRBTOs, 27]
# 232               [224, MRRAGA, 11:27, 12.34, NUNEBROTOs]
# 233         [=3, [2924, MRRAGA, 00:45, 01.21, NUNEBRQTOS]
# 234                                             [CLARINS]
# 235         [=3, 22, MORRAGA, 04837, 04:06, NUNEBRQTos |]
# 236          [3, 8262, MORRAGA, 14850, 15.06, NUNEBRQTOS]
# 237         [3, 22, MPARIAGA, 14803, 14*31, NUNPEBRPTos ]
# 238          [224, MORRIAGUA, 07.58, 06.38, NUNPEBRPTos ]
# 239                                             [73, 224]
# 240     [23, 2, MARIANA, 01:45, 02.34, PEDRO, 5, MORTÁ...
# 241                [2124, MRRAAA, 05.43, O6:OONuNgR Tos ]
# 242          [=3, 224, MORRAGA, 04-23, 04:06, NUNEBRQTOS]
# 243        [33, 82624, MORRAAA, 10.39, 10.51, NUNEBRQTOS]
# 244      [23, MOARIAGHA, 07.58, 07.01, NUNEBROTOs , 2424]
# 245          [3, MORRAGA, 07.58, 09.32, NUNEBROTOs , 224]
# 246        [0, MORRAAA, 11.27, 10:58, NUNEBROTos |, 2424]
# 247        [3, 5, 22, MRRAGA, 14803, 15.03, NUNPEBRPTos ]
# 248       [3, 0, 202, MORRAAA, 14803, 1440, NUNEBROTOs |]
# 249     [3, 2 ), @, 224, MORRAGA, 01:45, 02.43, NUNPEB...
# 250         [3, 8224, MRRAAA, 07-58, 10.02, NUNEBROTos |]
# 251        [=3, [2424, MORRAGA, 05:11, 04:06, NUNEBRQTOS]
# 252        [=3, 82624, MORRAAA, 00:14, 01.21, NUNEBRQTOS]
# 253             [22, MORRAGA, 04:07, 04:05, NUNEBRQTOs |]
# 254     [=3, ª, MORRAGA, 0141, 0121, NUNEBRQTOS, 9, 2924]
# 255      [=3, 1, 2624, MORRAAA, 02.03, 03.06 NuNPEBR?ToS]
# 256             [27, MORRAGA, 13.04, 13.59, NUNEBROTos |]
# 257     [KaS, 5, 2424, MRRAGA, 01:45, 01.35, NUNEBROTO...
# 258      [3, 0), 22, MORRAAA, 07.58, 09.59, NUNPEBRPTos ]
# 259        [33, 2122, MORRAAA, 11.27, 12.37, NUNPEBRPTOS]
# 604         [=3, 8262, MORRAAA, 05.03, 04:06, NUNEBRQTOS]
# 605          [2, 224, MORRAAA, 11.27, 12.42, [NUNEBR Tos]
# 606     [23, ª, 2424, MORRAGA, 00:00l0o.32, NUNPEBRPTos ]
# 607      [23, 1, MORRAGA, 02.10, 03.06, NUNEBRQTOS, 2924]
# 608         [23, 22, MORRAAA, 07:01, 06.02, NUNPEBRPTos ]
# 609     [23, 5, MRRAGA, 01:45, 02.02, NUNPEBRPTos , 1,...
# 610      [=3, 1, MORRAGA, 02.58, 03.06, NUNEBRQTOS, 2924]
# 611             [224, MRRAGA, 06.25, 06.02, NUNPEBRPTos ]
# 612        [3, 2, 27, MORRAGA, 14803, 14:19, NUNEBROTOs ]
# 613         [23, 924, MORRAGA, 07-58, 07.33, NUNEBRBTOs ]
# 614           [=3, MORRAGA, 11.27, 1122, NUNEBRQTOS, 7ac]
# 615          [23, 224, MORRAGA, 10.16, 1011, NUNEBRQTOs ]
# 616        [73, MOARIAGHA, 10.33, 10.36, NUNPEBRPTOS, 94]
# 617        [3, MORRAGA, 10.33, 10.28, [NUNPEBRPTos , 724]
# 618               [224, MORRAGA, 08.46, 1O.02 NuNBR Tos ]
# 619                                                    []
# 620             [=a, 27, MORRAGA, 1125, 1051, NUNEBRQTOS]
# 621      [1, MOARIAGHA, 08.19, 10.02, NUNPEBRPTos , 2924]
# 622      [3, 2, MORRAGA, 01.45, 01.28, NUNEBROTos |, 224]
# 623      [=3, {2524, MORRAAA, 07-58, 10.02, NUNPEBRPTos ]
# 624     [=3, 9, {2124, MRRAGA, 05.43, 05.51, NUNEBROTOs ]
# 625         [=3, 8202, MORRAGA, 11.36, 13-59, NUNEBRQTOS]
# 626           [3, MORRAGA, 07-58, 09.49, NUNEBRPTos, 224]
# 627           [3, MORRAAA, 10.32, 10.16, NUNEBRQTOs, 924]
# 628           [2124, MOARIAGHA, 07.58, 09.07, NUNEBRQTOS]
# 629             [2824, MORRAGA, 07-58, 09.07, NUNEBRQTOS]
# 630             [MORRAGA, 12.42, 13-59, NUNPEBRPTos , 77]
# 631         [73, 8212 , MORRAAA, 14:03, 1445, NUNEBRQTOS]
# 632        [3, 2624, MORRAGA, 07.58, 06.14, NUNPEBRPTos ]
# 633     [=3, MARIANA MORTÁGUA, BE, 82524, MRRAGA, 00:0...
# 634     [=3, {2624, MORRAGA, 07.58, 09.47, NUNEBRQTOS, 9]
# 635         [3, 224, MORRAGA, 07-58, 06.04, NUNEBROTos |]
# 636       [23, MORRAGA, 07.58, 06.58, NUNPEBRPTos , 7424]
# 637            [224, MORRAAA, 06.33, 06.02, NUNEBRQTOs |]
# 638         [3, 82524, MORRAAA, 14834, 15.06, NUNEBRQTOS]
# 639       [3, [2424, MRRAGA, OO:OO, 01:06, NUNEBRQTOS, 9]
# 640     [3;, 2(24 ,, EsLATv, [, MRRAAA, OO:OOOO:OONunB...
# 641     [2, 9, MORRAGA, 01:45, 02.55, [NUNEBRPTos , 2424]
# 642      [=3, 1, MORRAGA, 01.45, 03.06, NUNEBRQTOS, 2524]
# 759           [3, MORRAGA, 07.58, 08:OONuNEgR Tos , 9641]
# 760          [=3, 2654, MORRAGA, 0112, 01.21, NUNEBRQTOS]
# 761             [224, MORRAGA, 10.37, 10.51, NUNEBRQTOs ]
# 762          [254, MOARIAQUA, 06.45, 06.02, NUNEBRQTos |]
# 763      [=3, 1, MORRAAA, 02.49, 03.06, NUNEBRQTOS, 2524]
# 764      [=3, [2624, MRRAAA, 05.27, 04:06, NUNEBRQTOS, 9]
# 765       [01, P, [24, MORRAGA, 08.41, 10.02, NUNEBRQTOS]
# 766            [22, MPARIAGA, 11.27, 13.24, NUNPEBRPTos ]
# 767          [3, MRRAGA, 01:45, 01.23, NUNEBROTos |, 224]
# 768          [3, 254, MRRAGHA, 12.34, 13.59, [NUNEBRPTos]
# 769       [3, [2924, MOARIAGUA, 07.32, 06.02, NUNEBRQTOS]
# 770             [224, MORRAGA, 06.31, 06.02, NUNEBRPTos ]
# 771            [224, MORRAGGA, 10.30, 1011, NUNEBROTos |]
# 772         [523, 221, MRRAGA, 05.43, 04-50, [NUNEBR Tos]
# 773        [=3, [2924, MORRAAA, 10.41, 10.51, NUNEBRQTOS]
# 774      [=3, 1, MORRAAA, 11.27, 11.02, NUNEBRQTOS, 2924]
# 775                [2=, MORRAGA, 13.52, 1405 NungR ros |]
# 776               [MORRAGA, 07.58, 06.30 NuNBR Tos, 9024]
# 777             [=3, MORRAAA, OO:OOOO:OONunEPRPTos, 9654]
# 778            [22, MPARIAGA, 10.18, 10.11, NUNEBRQTOs |]
# 779            [MORRAGA, 13.56, 1405, NUNEBRQTos |, 2424]
# 780               [23, 2124, MRRAGA, OO:OOOO:OONunBR?Tos]
# 781     [3, 1), 8, MRRAGA, 01.45, 0153, NUNPEBRPTos , ...
# 782       [3, 0), 22, MORRAGA, 14:03, 1415, NUNPEBRPTos ]
# 783          [[2524, MORRAGA, 15.07, 15.06 NUNPEBRBTos /]
# 784        [3, 0), 22, MORRAGA, 00:000O:46, NUNPEBRPTos ]
# 785        [1, 2424, MORRAAA, 03.32, 04:05, NUNPEBRPTos ]
# 786     [=3, PLIR, 1, MORRAGA, 05.43, 06.00, NUNEBRQTO...
# 787     [3, 2), @, MRRAGA, 01:45, 02.59, NUNEBRPTOs , ...
# 788     [3, 0), MORRAAA, 14:03, 14:09, NUNEBRQTos |, 2...
# 789     [3, 5s, É, 2024, MORRAGA, 03.14, 03.26, NUNPEB...
# 790          [=3, 825, MORRAGA, 11.37, 13-59, NUNEBRQTOS]
# 791        [3, MORRAAA, 12.35, 13.59, NUNEBROTOs |, 9674]
# 792         [23, 2624, MRRAGA, 05.43, 04-16, NUNEBROTOs ]
# 793     [723, VAs, , MRRAGA, 01:45, 01.37, NUNEBROTOS,...
# 794         [23, MORRAGA, 06.54, 06.02, NUNEBRQTOs |, 75]
# 795             [221, MRRAGA, 12.49, 13.59, NUNPEBRPTos ]
# 796              [22, MORRAAA, 11.27, 13.37, NUNEBRQTOs ]
# 797       [=3, MORRAGA, 11.27, 12.38, NUNPEBRPTOS, '2424]
# 1995       [73, MORRAGA, 10.33, 10.35, NUNPEBRPTOS, 9494]
# 1996       [3, 82624, MORRAAGA, O2:01, 03.06, NUNEBRQTOS]
# 1997     [73, 2024, MORRAGA, 03.14, 03.31, NUNPEBRPTos |]
# 1998    [=3, 1, MARIANA, PEDRO, 9, MORTÁGUA, 01:47, 03...
# 1999        [7=3, 224, MORRAGA, 08.43, 10.02, NUNEBR TOS]
# 2000    [3, 0, #, [2624, MPRRIAGA, 03.14, 04:05, NUNPE...
# 2001    [3, 2, [, MRRAAA, 01:45, 02.21, NUNPEBRPTos , ...
# 2002    [23, [, MRRAGGA, 01:45, 01:59, NUNEBRQTos |, 2...
# 2003      [=3, 82624, MORRIAAA, 02.02, 03.06, NUNEBRQTOS]
# 2004                            [23, 24, SuTNas, ª, 2924]
# 2005              [22, MORRAGA, 06:17, 06:02, NUNEBROTOS]
# 2006     [24, {2(24, MORRAGA, 11:29, 13.59, NUNPEBRPTos ]
# 2007       [23, 8202, MPRFIAGA, 11:29, 13.59, NUNEBRQTOS]
# 2008      [=3, MORRIAGHA, 11.27, 12.45, NUNEBRBTOs , 745]
# 2009        [2, 22, MORRAAA, 11-27, 10.59, [NUNPEBRPTos ]
# 2010         [3, 224, MORRAAA, 01:14, 0121, [NUNPEBRQTOS]
# 2011       [3, 2124, MORRAAA, 05.43, 04-28, NUNPEBRPTos ]
# 2012          [3, 22, MZRRAAA, 01.27, 0121, NUNEBRQTos |]
# 2013    [728, 0), 22, MORRAGA, 14803, 1410, NUNPEBRPTos ]
# 2014         [MPARIAGA, 09.49, 10.11, [NUNPEBRQTos , 724]
# 2015    [=3, [2524, MORRAGA, 10.45, 10.51, NUNEBRQTOS, 9]
# 2016         [3, [2924, MRRAGA, 10.55, 10.51, NUNEBRQTOS]
# 2017      [=3, 22, MORRIAGHA, 07-58, 07.34, NUNPEBRPTos ]
# 2018    [9, 2924, MORRAAA, 12.39, 13.59, NUNPEBRPTos , 2]
# 2019                                                  [3]
# 2020       [73, [2424, MORRAAA, 02.23, 03.06, NUNEBRQTOS]
# 2021    [3, 1, 5, 22, MRRAGA, 01:45, 01.48, NUNPEBRPTos ]
# 2022     [=3, [2424, MRRAAA, 14:03, 14.05, NUNEBRQTOS, 9]
# 2023      [31, MORRAGA, 11.27, 12.02, NUNEBRPTos |, 7124]
# 2024        [=3, 22, MOARIAGHA, 01:19, 0121, [NUNEBRQTOS]
# 2025                                                [RTP]
# 2026    [3, 2, [, MORRAGA, OO:OOlOO:17, NUNPEBRPTos , ...
# 2027        [73, MRRAGA, 04-28, 04:06, NUNEBROTOs , 2424]
# 2028        [=3, {202, MORRAGA, 1134, 13.59, INUNEBRPTos]
# 2029         [3, 2, MORRAGA, 11.27, 12.06, NUNEBRQTOS, 2]
# 2030            [MORRAGA, 08.57, 10.02, NUNEBRBTOs , 224]
# 2031          [82424, MORRAGHA, 07-58, 08.43, NUNEBRQTOs]
# 2032        [@, 224, MRRIAAA, 14:03, 1405, NUNEBRQTOS, 9]
# 2256       [3, 26241, MORRAAA, 13.32, 1401, NUNEBROTOs |]
# 2257    [=3, Aa, 82624, MORRAGA, 00:20, 0121, NUNEBRQTOS]
# 2258      [=3, ª, 212, MORRAAA, 07.53, 06.02, NUNEBRQTOS]
# 2259               [22, MORRAAGA, 06.35, 06:02 NuNBR Tos]
# 2260     [=3, [2424, MRRAAA, 05.28, 04:06, NUNEBRQTOS, 9]
# Name: text, dtype: object

# %%
#Analyse and clean text

def time_str_to_float(time_str):
    # Split the string on the period to separate minutes and seconds
    minutes_str, seconds_str = time_str.split('.')
    # Convert strings to integer and float, respectively
    minutes = int(minutes_str)
    seconds = float(seconds_str)
    # Convert seconds to a fraction of a minute
    seconds_fraction = seconds / 60.0
    # Return as float
    return minutes + seconds_fraction

#first lets order the images

data = data.sort_values(by='filename')


pd.set_option('display.max_rows', None)


count = 0


pattern_n = r'\bN\w+\b'

pattern_m = r'\bM\w+\b'

count = 0

Used_list = []


# Iterate over the rows of the DataFrame starting from index 73
for i in range(119, len(data)):

    # Extract the list from the specified column
    data_inside = data.iloc[i, 4]

    # Iterate over each string in the list
    for j in range(len(data_inside)):

        # Check if the pattern matches the string
        if re.search(pattern_m, data_inside[j]):
            

            # If pattern is found, extract the current string and the next three strings
            desired_info = data_inside[j:j+4]  # Extract the next three strings

            # Translate "MO..." to "Montenegro" and "v..." to "Ventura"
            translated_info = []
            for item in desired_info:
                if re.match(pattern_m, item):
                    translated_info.append("Mariana Mortágua")
                elif re.match(pattern_n, item):
                    translated_info.append("Pedro Nuno Santos")
                else:
                    translated_info.append(item)

            # Append the translated_info to Used_list
            Used_list.append(translated_info)


# Filter out lists with exactly 4 objects
Used_list = [desired_info for desired_info in Used_list if len(desired_info) == 4]

Used_list = [sublist for sublist in Used_list if "PEDRO NUNO SANTOS" not in sublist]


# Initialize arrays to store Montenegro and Ventura times
PNS_times2 = []
Mortagua_times = []


for list in Used_list:
 
    # Get the first two characters
    first_part_m = list[1][:2]

    # Get the last two characters
    second_part_m = list[1][-2:]

    first_part_v = list[2][:2]

    second_part_v = list[2][-2:]
    
     # Join the PNS parts with a period in the middle
    PNS_time1 = f"{first_part_m}.{second_part_m}"

    # Join the Mortagua parts with a period in the middle
    Mortagua_time = f"{first_part_v}.{second_part_v}"
    
    # Append the times to the arrays
    PNS_times2.append(PNS_time1)
    Mortagua_times.append(Mortagua_time)


PNS_times2 = [time.replace('O', '0').replace('I', '1').replace('l', '1') for time in PNS_times2]
Mortagua_times = [time.replace('O', '0').replace('I', '1').replace('l', '1') for time in Mortagua_times]

print(PNS_times2)
print(Mortagua_times)

PNS_times_filtered1 = [time for time in PNS_times2 if 'BE' not in time and 'PE' not in time and 'Pe' not in time and 'Ma' not in time]
Mortagua_times_filtered = [time for time in Mortagua_times if 'Ru' not in time and 'os' not in time and 'oS' not in  time and '0S' not in time and ' |' not in time and ' /' not in time and 's ' not in time and ' !' not in time and 'Ma' not in time and 's_' not in time and '1b' not in time]

print(PNS_times_filtered1)
print(Mortagua_times_filtered)

# Now the conversion again
PNS_minutes_filtered2 = [time_str_to_float(time) for time in PNS_times_filtered1]
Mortagua_minutes_filtered = [time_str_to_float(time) for time in Mortagua_times_filtered]


#############################################  Outliers Detection  #############################################

# New lists to store the filtered results
PNS_minutes_filtered2_no_outliers = []
Mortagua_minutes_filtered_no_outliers = []

for index, time in enumerate(Mortagua_minutes_filtered):
    if index < 500 and time <= 6:
        Mortagua_minutes_filtered_no_outliers.append(time)
    elif 500 <= index < 1000:
        Mortagua_minutes_filtered_no_outliers.append(time)
    elif 1000 <= index < 1250 and time >= 6:
        Mortagua_minutes_filtered_no_outliers.append(time)
    elif index >= 1250:
        Mortagua_minutes_filtered_no_outliers.append(time)


####################################### Plot the Filtered Data with Outliers Removed  #######################################

# Assume PNS_minutes_filtered2 and Mortagua_minutes_filtered_no_outliers are available and contain filtered data.

total_debate_time = 40  # Total time for the debate in minutes
total_speech_turns = max(len(PNS_minutes_filtered2), len(Mortagua_minutes_filtered_no_outliers))

# Calculate the average duration per speech turn in minutes
average_duration_per_turn = total_debate_time / total_speech_turns

# Generate x-axis values corresponding to the actual time in minutes
x_axis_time = [i * average_duration_per_turn for i in range(total_speech_turns)]

plt.figure(figsize=(10, 6))  # Increased figure size for better visibility

# Use the same x-axis for both speakers, assuming both arrays cover the entire debate duration
plt.plot(x_axis_time[:len(PNS_minutes_filtered2)], PNS_minutes_filtered2, label='Pedro Nuno Santos', linewidth=2.5)
plt.plot(x_axis_time[:len(Mortagua_minutes_filtered_no_outliers)], Mortagua_minutes_filtered_no_outliers, label='Mariana Mortagua', linewidth=2.5)

# Add labels and title with more description
plt.xlabel('Time (minutes)')
plt.ylabel('Speaking Time (minutes)')
plt.title('Speaking Time Evolution for Pedro Nuno Santos and Mariana Mortagua')

# Enhance the legend
plt.legend(loc='upper left', fontsize='large', frameon=True, shadow=True)

# Show the plot with an enhanced grid for better readability and axis range adjustment
plt.grid(True, linestyle='--', alpha=0.7)  # Enhanced grid visibility
plt.xlim(left=0, right=total_debate_time)  # Adjusted for the total duration of the debate
plt.ylim(bottom=0, top=max(max(PNS_minutes_filtered2), max(Mortagua_minutes_filtered_no_outliers)) + 1)  # Set dynamic upper limit based on max speaking time

plt.tight_layout()  # Adjust the padding between and around subplots
plt.show()
# Out:
# ['00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', '00.00', 'BE.BE', '00.01', 'BE.BE', '00.02', 'BE.BE', '00.03', 'BE.BE', '00.04', 'BE.BE', '00.05', '00.06', '00.07', '00.08', '00.09', '00.10', '00.11', '00.12', '00.13', '00.14', '00.15', '00.16', '00.17', '00.18', '00.19', '00.20', '00.21', '00.22', '00.23', '00.24', '00.25', '00.26', '00.27', '00.28', '00.29', 'PE.R0', '00.30', '00.31', '00.32', '00.33', '00.34', '00.35', '00.36', '00.37', '00.38', '00.39', '00.39', '00.39', '00.39', '00.39', '00.39', '00.39', '00.39', '00.39', '00.40', '00.41', '00.42', '00.43', '00.44', '00.45', '00.46', '00.47', '00.48', '00.49', '00.50', '00.51', '00.52', '00.53', '00.54', '
'01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.37', '01.38', '01.39', '01.40', '01.41', '01.42', '01.43', '01.44', '01.45', '01.46', '01.47', '01.48', '01.49', '01.50', '01.51', '01.52', '01.53', '01.54', '01.55', '01.56', '01.57', '01.58', '01.59', '02.00', '02.01', '02.02', '02.03', '02.04', '02.05', '02.06', '02.07', '02.08', '02.09', '02.10', '02.11', '02.12', '02.13', '02.14', '02.15', '02.16', '02.17', '02.18', '02.19', '02.20', '02.21', '02.22', '02.23', '02.24', '02.25', '02.26', '02.27', '02.28', '02.29', '02.30', '02.31', '02.32', '02.33', '02.34', '7.7', '02.35', '02.36', '02.37', '02.38', '02.39', '02.40', '02.41', '02.42', '02.43', '02.44', '02.44', '02.44', '02.44', '02.44', '02.44', '02.45', '02.46', '02.47', '02.48', '02.49', '02.50', '02.51', '02.52', '02.53', '02.54', '02.55', '02.56', '02.57', '02.58', '02.59', '03.01', '03.02', '03.03', '03.04', '03.05', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '9.9', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.06', '03.07', '03.08', '03.09', '03.10', '03.11', '03.12', '03.13', '03.14', '03.15', '03.16', '03.17', '03.18', '03.19', '03.20', '03.21', '03.22', '03.23', '03.24', '03.25', '03.26', '03.27', '03.28', '03.29', '03.30', '03.31', '03.32', '03.33', '03.34', '03.35', '03.36', '03.37', '03.38', '03.39', '03.40', '03.41', '03.42', '03.43', '0 ...

# %% [markdown]
# NOW CHEGA VS BE

# %%
# Load the pickle file into a DataFrame
data = pd.read_pickle('chega-be.pkl')

# %%
#Analyse and clean text

def time_str_to_float(time_str):
    # Split the string on the period to separate minutes and seconds
    minutes_str, seconds_str = time_str.split('.')
    # Convert strings to integer and float, respectively
    minutes = int(minutes_str)
    seconds = float(seconds_str)
    # Convert seconds to a fraction of a minute
    seconds_fraction = seconds / 60.0
    # Return as float
    return minutes + seconds_fraction

#first lets order the images

data = data.sort_values(by='filename')

count = 0
'''
for i in range(len(data)):
    count = count +1
    print("count: " + str(count) + " data: " + str(data.iloc[i, 4]))
'''
pd.set_option('display.max_rows', None)



Used_list = []


# Iterate over the rows of the DataFrame starting from index 73
for i in range(53, 2184):

    # Extract the list from the specified column
    data_inside = data.iloc[i, 4]

    # Iterate over each string in the list
    for j in range(len(data_inside)):

        # Check if the pattern matches the string
        if re.search(pattern_m, data_inside[j]):
            

            # If pattern is found, extract the current string and the next three strings
            desired_info = data_inside[j:j+4]  # Extract the next three strings

            # Translate "MO..." to "Montenegro" and "v..." to "Ventura"
            translated_info = []
            for item in desired_info:
                if re.match(pattern_m, item):
                    translated_info.append("Mariana Mortágua")
                elif re.match(pattern_v, item):
                    translated_info.append("André Ventura")
                else:
                    translated_info.append(item)

            # Append the translated_info to Used_list
            Used_list.append(translated_info)


# Filter out lists with exactly 4 objects
Used_list = [desired_info for desired_info in Used_list if len(desired_info) == 4]


# Initialize arrays to store Montenegro and Ventura times
Andre_times = []
Mariana_times = []


for list in Used_list:
 
    # Get the first two characters
    first_part_m = list[1][:2]

    # Get the last two characters
    second_part_m = list[1][-2:]

    first_part_v = list[2][:2]

    second_part_v = list[2][-2:]
    
     # Join the PNS parts with a period in the middle
    Andre_time = f"{first_part_m}.{second_part_m}"

    # Join the Mortagua parts with a period in the middle
    Mariana_time = f"{first_part_v}.{second_part_v}"
    
    # Append the times to the arrays
    Mariana_times.append(Mariana_time)
    Andre_times.append(Andre_time)


Mariana_times = [time.replace('O', '0').replace('I', '1').replace('l', '1') for time in Mariana_times]
Andre_times = [time.replace('O', '0').replace('I', '1').replace('l', '1') for time in Andre_times]


Mariana_times_filtered = [time for time in Mariana_times if '{2' not in time and '[2' not in time and '0]' not in time and '@' not in time and 'BE' not in time]
Andre_times_filtered = [time for time in Andre_times if 'BE' not in time and 'AN' not in time ]


Mariana_minutes_filtered = [time_str_to_float(time) for time in Mariana_times_filtered]
Andre_minutes_filtered = [time_str_to_float(time) for time in Andre_times_filtered]


#############################################  Outliers Detection  #############################################
# New lists to store the filtered results
Mariana_minutes_filtered_no_outliers = []

for index, time in enumerate(Mariana_minutes_filtered):
    if index < 1000:
        Mariana_minutes_filtered_no_outliers.append(time)
    elif 1000 <= index < 1250 and time <= 15 and time >= 5:
        Mariana_minutes_filtered_no_outliers.append(time)
    elif index >= 1250 :
        Mariana_minutes_filtered_no_outliers.append(time)
   

####################################### Plot the Filtered Data with Outliers Removed  #######################################

total_debate_time = 40  # Assuming the total time for the debate in minutes
total_speech_turns = max(len(Mariana_minutes_filtered_no_outliers), len(Andre_minutes_filtered))

# Calculate the average duration per speech turn in minutes, if you have a total count of turns
average_duration_per_turn = total_debate_time / total_speech_turns

# Generate x-axis values corresponding to the actual time in minutes
x_axis_time = [i * average_duration_per_turn for i in range(total_speech_turns)]

plt.figure(figsize=(12, 8))  # Specify the figure size for better visibility

# Use the generated x-axis for both speakers to show actual time distribution across the debate
plt.plot(x_axis_time[:len(Mariana_minutes_filtered_no_outliers)], Mariana_minutes_filtered_no_outliers, label='Mariana Mortágua', linewidth=2.5)
plt.plot(x_axis_time[:len(Andre_minutes_filtered)], Andre_minutes_filtered, label='André Ventura', linewidth=2.5)

plt.fill_between(x_axis_time[:min(len(Mariana_minutes_filtered_no_outliers), len(Andre_minutes_filtered))], 
                  Mariana_minutes_filtered_no_outliers[:min(len(Mariana_minutes_filtered_no_outliers), len(Andre_minutes_filtered))], 
                  Andre_minutes_filtered[:min(len(Mariana_minutes_filtered_no_outliers), len(Andre_minutes_filtered))], color='grey', alpha=0.3)

# Add labels and title with more description
plt.xlabel('Time (minutes)')
plt.ylabel('Speaking Time (minutes)')
plt.title('Speaking Time Evolution for Mariana Mortágua and André Ventura')

# Enhance the legend
plt.legend(loc='upper left', fontsize='large', frameon=True, shadow=True)

# Show the plot with an enhanced grid for better readability and axis range adjustment
plt.grid(True, linestyle='--', alpha=0.7)
plt.xlim(left=0, right=total_debate_time)  # Adjust x-axis to cover the total debate duration
plt.ylim(bottom=0)  # Start y-axis at zero

plt.tight_layout()  # Adjust layout to fit elements neatly
plt.show()
